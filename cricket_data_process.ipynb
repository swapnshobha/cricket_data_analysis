# %%
import numpy as np
import pandas as pd

# %%
cric =pd.read_csv(r"C:\Users\Swarup\OneDrive - D Y Patil Education Society\Desktop\test.csv")

# %%
cric
# Out:
#       Serial_Number                Player       Span  Mat Inns  NO   Runs  \
# 0                 0  SR Tendulkar (INDIA)  1989-2013  200  329  33  15921
# 1                 1      RT Ponting (AUS)  1995-2012  168  287  29  13378
# 2                 2    JH Kallis (ICC/SA)  1995-2013  166  280  40  13289
# 3                 3  R Dravid (ICC/INDIA)  1996-2012  164  286  32  13288
# 4                 4         AN Cook (ENG)  2006-2018  161  291  16  12472
# ...             ...                   ...        ...  ...  ...  ..    ...
# 2996             46       CA Snedden (NZ)  1947-1947    1    -   -      -
# 2997             47      VN Swamy (INDIA)  1955-1955    1    -   -      -
# 2998             48  Usman Shinwari (PAK)  2019-2019    1    -   -      -
# 2999             49    CM Willoughby (SA)  2003-2003    2    -   -      -
# 3000              0       JW Wilson (AUS)  1956-1956    1    -   -      -
#
#         HS    Ave 100  50   0  Unnamed: 11
# 0     248*  53.78  51  68  14          NaN
# 1      257  51.85  41  62  17          NaN
# 2      224  55.37  45  58  16          NaN
# 3      270  52.31  36  63   8          NaN
# 4      294  45.35  33  57   9          NaN
# ...    ...    ...  ..  ..  ..          ...
# 2996     -      -   -   -   -          NaN
# 2997     -      -   -   -   -          NaN
# 2998     -      -   -   -   -          NaN
# 2999     -      -   -   -   -          NaN
# 3000     -      -   -   -   -          NaN
#
# [3001 rows x 13 columns]

# %%
cric.isna().sum()
# Out:
# Serial_Number       0
# Player              0
# Span                0
# Mat                 0
# Inns                0
# NO                  0
# Runs                0
# HS                  0
# Ave                 0
# 100                 0
# 50                  0
# 0                   0
# Unnamed: 11      3001
# dtype: int64

# %%
df=cric.iloc[:,:-1]

# %%
df
# Out:
#       Serial_Number                Player       Span  Mat Inns  NO   Runs  \
# 0                 0  SR Tendulkar (INDIA)  1989-2013  200  329  33  15921
# 1                 1      RT Ponting (AUS)  1995-2012  168  287  29  13378
# 2                 2    JH Kallis (ICC/SA)  1995-2013  166  280  40  13289
# 3                 3  R Dravid (ICC/INDIA)  1996-2012  164  286  32  13288
# 4                 4         AN Cook (ENG)  2006-2018  161  291  16  12472
# ...             ...                   ...        ...  ...  ...  ..    ...
# 2996             46       CA Snedden (NZ)  1947-1947    1    -   -      -
# 2997             47      VN Swamy (INDIA)  1955-1955    1    -   -      -
# 2998             48  Usman Shinwari (PAK)  2019-2019    1    -   -      -
# 2999             49    CM Willoughby (SA)  2003-2003    2    -   -      -
# 3000              0       JW Wilson (AUS)  1956-1956    1    -   -      -
#
#         HS    Ave 100  50   0
# 0     248*  53.78  51  68  14
# 1      257  51.85  41  62  17
# 2      224  55.37  45  58  16
# 3      270  52.31  36  63   8
# 4      294  45.35  33  57   9
# ...    ...    ...  ..  ..  ..
# 2996     -      -   -   -   -
# 2997     -      -   -   -   -
# 2998     -      -   -   -   -
# 2999     -      -   -   -   -
# 3000     -      -   -   -   -
#
# [3001 rows x 12 columns]

# %%
df.isna().sum()
# Out:
# Serial_Number    0
# Player           0
# Span             0
# Mat              0
# Inns             0
# NO               0
# Runs             0
# HS               0
# Ave              0
# 100              0
# 50               0
# 0                0
# dtype: int64

# %%
df.head()
# Out:
#    Serial_Number                Player       Span  Mat Inns  NO   Runs    HS  \
# 0              0  SR Tendulkar (INDIA)  1989-2013  200  329  33  15921  248*
# 1              1      RT Ponting (AUS)  1995-2012  168  287  29  13378   257
# 2              2    JH Kallis (ICC/SA)  1995-2013  166  280  40  13289   224
# 3              3  R Dravid (ICC/INDIA)  1996-2012  164  286  32  13288   270
# 4              4         AN Cook (ENG)  2006-2018  161  291  16  12472   294
#
#      Ave 100  50   0
# 0  53.78  51  68  14
# 1  51.85  41  62  17
# 2  55.37  45  58  16
# 3  52.31  36  63   8
# 4  45.35  33  57   9

# %%
df.tail()
# Out:
#       Serial_Number                Player       Span  Mat Inns NO Runs HS Ave  \
# 2996             46       CA Snedden (NZ)  1947-1947    1    -  -    -  -   -
# 2997             47      VN Swamy (INDIA)  1955-1955    1    -  -    -  -   -
# 2998             48  Usman Shinwari (PAK)  2019-2019    1    -  -    -  -   -
# 2999             49    CM Willoughby (SA)  2003-2003    2    -  -    -  -   -
# 3000              0       JW Wilson (AUS)  1956-1956    1    -  -    -  -   -
#
#      100 50  0
# 2996   -  -  -
# 2997   -  -  -
# 2998   -  -  -
# 2999   -  -  -
# 3000   -  -  -

# %%
df.sample(5)
# Out:
#       Serial_Number               Player       Span  Mat Inns NO  Runs   HS  \
# 2174             24  WB Rankin (ENG/IRE)  2014-2019    3    6  1    43   17
# 1620             20        RJ Crisp (SA)  1935-1936    9   13  1   123   35
# 1942             42      AC Waller (ZIM)  1996-1996    2    3  0    69   50
# 84               34       JB Hobbs (ENG)  1908-1930   61  102  7  5410  211
# 1065             15     CR Matthews (SA)  1992-1995   18   25  6   348  62*
#
#         Ave 100  50  0
# 2174    8.6   0   0  1
# 1620  10.25   0   0  5
# 1942   23.0   0   1  0
# 84    56.94  15  28  4
# 1065  18.31   0   1  4

# %%
df.isin(['-']).sum()
# Out:
# Serial_Number     0
# Player            0
# Span              0
# Mat               0
# Inns             20
# NO               20
# Runs             20
# HS               20
# Ave              88
# 100              20
# 50               20
# 0                20
# dtype: int64

# %%
df=df.replace('-',0)

# %%
df.tail()
# Out:
#       Serial_Number                Player       Span  Mat Inns NO Runs HS Ave  \
# 2996             46       CA Snedden (NZ)  1947-1947    1    0  0    0  0   0
# 2997             47      VN Swamy (INDIA)  1955-1955    1    0  0    0  0   0
# 2998             48  Usman Shinwari (PAK)  2019-2019    1    0  0    0  0   0
# 2999             49    CM Willoughby (SA)  2003-2003    2    0  0    0  0   0
# 3000              0       JW Wilson (AUS)  1956-1956    1    0  0    0  0   0
#
#      100 50  0
# 2996   0  0  0
# 2997   0  0  0
# 2998   0  0  0
# 2999   0  0  0
# 3000   0  0  0

# %%
player=df.iloc[:,1:2]
player=np.array(player)
player
# Out:
# array([['SR Tendulkar (INDIA)'],
#        ['RT Ponting (AUS)'],
#        ['JH Kallis (ICC/SA)'],
#        ...,
#        ['Usman Shinwari (PAK)'],
#        ['CM Willoughby (SA)'],
#        ['JW Wilson (AUS)']], dtype=object)

# %%
p_name=[]
country=[]
for i in range(3000):
    for i in player[i]:
        pi.split("("))
        p_name=
# Out:
# ['SR Tendulkar ', 'INDIA)']
# ['RT Ponting ', 'AUS)']
# ['JH Kallis ', 'ICC/SA)']
# ['R Dravid ', 'ICC/INDIA)']
# ['AN Cook ', 'ENG)']
# ['KC Sangakkara ', 'SL)']
# ['BC Lara ', 'ICC/WI)']
# ['S Chanderpaul ', 'WI)']
# ['DPMD Jayawardene ', 'SL)']
# ['AR Border ', 'AUS)']
# ['SR Waugh ', 'AUS)']
# ['SM Gavaskar ', 'INDIA)']
# ['Younis Khan ', 'PAK)']
# ['HM Amla ', 'SA)']
# ['GC Smith ', 'ICC/SA)']
# ['GA Gooch ', 'ENG)']
# ['Javed Miandad ', 'PAK)']
# ['Inzamam-ul-Haq ', 'ICC/PAK)']
# ['VVS Laxman ', 'INDIA)']
# ['AB de Villiers ', 'SA)']
# ['MJ Clarke ', 'AUS)']
# ['ML Hayden ', 'AUS)']
# ['V Sehwag ', 'ICC/INDIA)']
# ['IVA Richards ', 'WI)']
# ['AJ Stewart ', 'ENG)']
# ['DI Gower ', 'ENG)']
# ['KP Pietersen ', 'ENG)']
# ['G Boycott ', 'ENG)']
# ['GS Sobers ', 'WI)']
# ['ME Waugh ', 'AUS)']
# ['MA Atherton ', 'ENG)']
# ['IR Bell ', 'ENG)']
# ['JL Langer ', 'AUS)']
# ['MC Cowdrey ', 'ENG)']
# ['CG Greenidge ', 'WI)']
# ['Mohammad Yousuf ', 'PAK)']
# ['MA Taylor ', 'AUS)']
# ['CH Lloyd ', 'WI)']
# ['DL Haynes ', 'WI)']
# ['DC Boon ', 'AUS)']
# ['JE Root ', 'ENG)']
# ['G Kirsten ', 'SA)']
# ['WR Hammond ', 'ENG)']
# ['CH Gayle ', 'WI)']
# ['SC Ganguly ', 'INDIA)']
# ['V Kohli ', 'INDIA)']
# ['SP Fleming ', 'NZ)']
# ['SPD Smith ', 'AUS)']
# ['LRPL Taylor ', 'NZ)']
# ['GS Chappell ', 'AUS)']
# ['DA Warner ', 'AUS)']
# ['AJ Strauss ', 'ENG)']
# ['DG Bradman ', 'AUS)']
# ['ST Jayasuriya ', 'SL)']
# ['L Hutton ', 'ENG)']
# ['DB Vengsarkar ', 'INDIA)']
# ['KF Barrington ', 'ENG)']
# ['GP Thorpe ', 'ENG)']
# ['BB McCullum ', 'NZ)']
# ['KS Williamson ', 'NZ)']
# ['PA de Silva ', 'SL)']
# ['MEK Hussey ', 'AUS)']
# ['RB Kanhai ', 'WI)']
# ['M Azharuddin ', 'INDIA)']
# ['HH Gibbs ', 'SA)']
# ['RN Harvey ', 'AUS)']
# ['GR Viswanath ', 'INDIA)']
# ['RB Richardson ', 'WI)']
# ['Azhar Ali ', 'PAK)']
# ['RR Sarwan ', 'WI)']
# ['ME Trescothick ', 'ENG)']
# ['DCS Compton ', 'ENG)']
# ['Saleem Malik ', 'PAK)']
# ['N Hussain ', 'ENG)']
# ['CL Hooper ', 'WI)']
# ['CA Pujara ', 'INDIA)']
# ['MP Vaughan ', 'ENG)']
# ['AD Mathews ', 'SL)']
# ['AC Gilchrist ', 'AUS)']
# ['MV Boucher ', 'ICC/SA)']
# ['MS Atapattu ', 'SL)']
# ['TM Dilshan ', 'SL)']
# ['TT Samaraweera ', 'SL)']
# ['MD Crowe ', 'NZ)']
# ['JB Hobbs ', 'ENG)']
# ['KD Walters ', 'AUS)']
# ['IM Chappell ', 'AUS)']
# ['JG Wright ', 'NZ)']
# ['MJ Slater ', 'AUS)']
# ['N Kapil Dev ', 'INDIA)']
# ['WM Lawry ', 'AUS)']
# ['Misbah-ul-Haq ', 'PAK)']
# ['IT Botham ', 'ENG)']
# ['JH Edrich ', 'ENG)']
# ['A Ranatunga ', 'SL)']
# ['Zaheer Abbas ', 'PAK)']
# ['TW Graveney ', 'ENG)']
# ['MS Dhoni ', 'INDIA)']
# ['RB Simpson ', 'AUS)']
# ['A Flower ', 'ZIM)']
# ['IR Redpath ', 'AUS)']
# ['NJ Astle ', 'NZ)']
# ['AJ Lamb ', 'ENG)']
# ['H Sutcliffe ', 'ENG)']
# ['DJ Cullinan ', 'SA)']
# ['HP Tillakaratne ', 'SL)']
# ['PBH May ', 'ENG)']
# ['DL Vettori ', 'ICC/NZ)']
# ['Asad Shafiq ', 'PAK)']
# ['ER Dexter ', 'ENG)']
# ['ED Weekes ', 'WI)']
# ['FDM Karunaratne ', 'SL)']
# ['KJ Hughes ', 'AUS)']
# ['MW Gatting ', 'ENG)']
# ['DR Martyn ', 'AUS)']
# ['AI Kallicharran ', 'WI)']
# ['APE Knott ', 'ENG)']
# ['M Amarnath ', 'INDIA)']
# ['IA Healy ', 'AUS)']
# ['RC Fredericks ', 'WI)']
# ['Tamim Iqbal ', 'BDESH)']
# ['MA Butcher ', 'ENG)']
# ['PD Collingwood ', 'ENG)']
# ['RA Smith ', 'ENG)']
# ['Mushfiqur Rahim ', 'BDESH)']
# ['SM Katich ', 'AUS)']
# ['G Gambhir ', 'INDIA)']
# ['Mudassar Nazar ', 'PAK)']
# ['AM Rahane ', 'INDIA)']
# ['MJ Prior ', 'ENG)']
# ['Saeed Anwar ', 'PAK)']
# ['JM Bairstow ', 'ENG)']
# ['M Vijay ', 'INDIA)']
# ['Majid Khan ', 'PAK)']
# ['MN Samuels ', 'WI)']
# ['Hanif Mohammad ', 'PAK)']
# ['Shakib Al Hasan ', 'BDESH)']
# ['FMM Worrell ', 'WI)']
# ['LD Chandimal ', 'SL)']
# ['A Flintoff ', 'ENG/ICC)']
# ['IJL Trott ', 'ENG)']
# ['RJ Shastri ', 'INDIA)']
# ['Imran Khan ', 'PAK)']
# ['F du Plessis ', 'SA)']
# ['CL Walcott ', 'WI)']
# ['BA Stokes ', 'ENG)']
# ['SM Pollock ', 'SA)']
# ['SR Watson ', 'AUS)']
# ['WJ Cronje ', 'SA)']
# ['D Elgar ', 'SA)']
# ['AG Prince ', 'SA)']
# ['Mohammad Hafeez ', 'PAK)']
# ['Mushtaq Mohammad ', 'PAK)']
# ['RW Marsh ', 'AUS)']
# ['DM Jones ', 'AUS)']
# ['PR Umrigar ', 'INDIA)']
# ['BJ Watling ', 'NZ)']
# ['DL Amiss ', 'ENG)']
# ['AW Greig ', 'ENG)']
# ['Asif Iqbal ', 'PAK)']
# ['TWM Latham ', 'NZ)']
# ['AR Morris ', 'AUS)']
# ['EH Hendren ', 'ENG)']
# ['DM Bravo ', 'WI)']
# ['KC Brathwaite ', 'WI)']
# ['B Mitchell ', 'SA)']
# ['GW Flower ', 'ZIM)']
# ['BE Congdon ', 'NZ)']
# ['JR Reid ', 'NZ)']
# ['C Hill ', 'AUS)']
# ['GA Hick ', 'ENG)']
# ['GM Wood ', 'AUS)']
# ['PJL Dujon ', 'WI)']
# ['CL Cairns ', 'NZ)']
# ['Ijaz Ahmed ', 'PAK)']
# ['FE Woolley ', 'ENG)']
# ['KWR Fletcher ', 'ENG)']
# ['BJ Haddin ', 'AUS)']
# ['ND McKenzie ', 'SA)']
# ['CC Hunte ', 'WI)']
# ['VL Manjrekar ', 'INDIA)']
# ['NS Sidhu ', 'INDIA)']
# ['HA Gomes ', 'WI)']
# ['VT Trumper ', 'AUS)']
# ['SCJ Broad ', 'ENG)']
# ['SK Warne ', 'AUS)']
# ['Sir RJ Hadlee ', 'NZ)']
# ['CD McMillan ', 'NZ)']
# ['CC McDonald ', 'AUS)']
# ['BF Butcher ', 'WI)']
# ['WPUJC Vaas ', 'SL)']
# ['AL Hassett ', 'AUS)']
# ['CG Borde ', 'INDIA)']
# ['Habibul Bashar ', 'BDESH)']
# ['JC Adams ', 'WI)']
# ['Saeed Ahmed ', 'PAK)']
# ['GM Turner ', 'NZ)']
# ['Taufeeq Umar ', 'PAK)']
# ['AD Nourse ', 'SA)']
# ['KR Miller ', 'AUS)']
# ['HW Taylor ', 'SA)']
# ['AH Jones ', 'NZ)']
# ['D Ramdin ', 'WI)']
# ['Wasim Akram ', 'PAK)']
# ['UT Khawaja ', 'AUS)']
# ['SL Campbell ', 'WI)']
# ['AC Parore ', 'NZ)']
# ['WW Armstrong ', 'AUS)']
# ['ADR Campbell ', 'ZIM)']
# ['GR Marsh ', 'AUS)']
# ['Rameez Raja ', 'PAK)']
# ['Aamer Sohail ', 'PAK)']
# ['Wasim Raja ', 'PAK)']
# ['KR Stackpole ', 'AUS)']
# ['MAK Pataudi ', 'INDIA)']
# ['KC Wessels ', 'AUS/SA)']
# ['MM Ali ', 'ENG)']
# ["NCL O'Neill ", 'AUS)']
# ['BKG Mendis ', 'SL)']
# ['MH Richardson ', 'NZ)']
# ['M Leyland ', 'ENG)']
# ['SMH Kirmani ', 'INDIA)']
# ['GN Yallop ', 'AUS)']
# ['SJ McCabe ', 'AUS)']
# ['Moin Khan ', 'PAK)']
# ['Mahmudullah ', 'BDESH)']
# ['Mohammad Ashraful ', 'BDESH)']
# ['B Sutcliffe ', 'NZ)']
# ['Mohsin Khan ', 'PAK)']
# ['Shoaib Mohammad ', 'PAK)']
# ['MG Burgess ', 'NZ)']
# ['Q de Kock ', 'SA)']
# ['JV Coney ', 'NZ)']
# ['Mominul Haque ', 'BDESH)']
# ['Sarfaraz Ahmed ', 'PAK)']
# ['Kamran Akmal ', 'PAK)']
# ['JA Rudolph ', 'SA)']
# ['FM Engineer ', 'INDIA)']
# ['WW Hinds ', 'WI)']
# ['MJ Guptill ', 'NZ)']
# ['Sadiq Mohammad ', 'PAK)']
# ['RD Jacobs ', 'WI)']
# ['RS Mahanama ', 'SL)']
# ['C Washbrook ', 'ENG)']
# ['GS Blewett ', 'AUS)']
# ['JN Rhodes ', 'SA)']
# ['GP Howarth ', 'NZ)']
# ['SM Nurse ', 'WI)']
# ['EJ Barlow ', 'SA)']
# ['TL Goddard ', 'SA)']
# ['A Kumble ', 'INDIA)']
# ["BL D'Oliveira ", 'ENG)']
# ['AL Logie ', 'WI)']
# ['DW Randall ', 'ENG)']
# ['W Bardsley ', 'AUS)']
# ['KR Rutherford ', 'NZ)']
# ['AP Gurusinha ', 'SL)']
# ['P Roy ', 'INDIA)']
# ['WJ Edrich ', 'ENG)']
# ['DJ McGlew ', 'SA)']
# ['TG Evans ', 'ENG)']
# ['LEG Ames ', 'ENG)']
# ['JHB Waite ', 'SA)']
# ['Imran Farhat ', 'PAK)']
# ['R Ashwin ', 'INDIA)']
# ['MR Ramprakash ', 'ENG)']
# ['W Rhodes ', 'ENG)']
# ['S Dhawan ', 'INDIA)']
# ['GT Dowling ', 'NZ)']
# ['WM Woodfull ', 'AUS)']
# ['TE Bailey ', 'ENG)']
# ['PJP Burge ', 'AUS)']
# ['SE Gregory ', 'AUS)']
# ['MJK Smith ', 'ENG)']
# ['SE Marsh ', 'AUS)']
# ['RG Pollock ', 'SA)']
# ['AW Nourse ', 'SA)']
# ['Harbhajan Singh ', 'INDIA)']
# ['H Masakadza ', 'ZIM)']
# ['GJ Whittall ', 'ZIM)']
# ['R Benaud ', 'AUS)']
# ['DJ Bravo ', 'WI)']
# ['VS Hazare ', 'INDIA)']
# ['GA Headley ', 'WI)']
# ['D Ganga ', 'WI)']
# ['JB Stollmeyer ', 'WI)']
# ['RG Sharma ', 'INDIA)']
# ['CG Macartney ', 'AUS)']
# ['HAPW Jayawardene ', 'SL)']
# ['WH Ponsford ', 'AUS)']
# ['RA McLean ', 'SA)']
# ['AL Wadekar ', 'INDIA)']
# ['MH Mankad ', 'INDIA)']
# ['JP Duminy ', 'SA)']
# ['JK Silva ', 'SL)']
# ['AN Petersen ', 'SA)']
# ['CPS Chauhan ', 'INDIA)']
# ['Imtiaz Ahmed ', 'PAK)']
# ['MG Johnson ', 'AUS)']
# ['K Srikkanth ', 'INDIA)']
# ['RM Cowper ', 'AUS)']
# ['PE Richardson ', 'ENG)']
# ['ML Jaisimha ', 'INDIA)']
# ['LG Rowe ', 'WI)']
# ['JC Buttler ', 'ENG)']
# ['SV Manjrekar ', 'INDIA)']
# ['BA Young ', 'NZ)']
# ['MJ Greatbatch ', 'NZ)']
# ['CJL Rogers ', 'AUS)']
# ['KOA Powell ', 'WI)']
# ['AC Hudson ', 'SA)']
# ['KL Rahul ', 'INDIA)']
# ['DN Sardesai ', 'INDIA)']
# ['TW Hayward ', 'ENG)']
# ['MA Noble ', 'AUS)']
# ['DL Murray ', 'WI)']
# ['HH Streak ', 'ZIM)']
# ['AD Gaekwad ', 'INDIA)']
# ['G Pullar ', 'ENG)']
# ['BM McMillan ', 'SA)']
# ['EAB Rowan ', 'SA)']
# ['JM Parks ', 'ENG)']
# ['BA Edgar ', 'NZ)']
# ['Abdul Razzaq ', 'PAK)']
# ['W Jaffer ', 'INDIA)']
# ['RS Kaluwitharana ', 'SL)']
# ['AC MacLaren ', 'ENG)']
# ['L Klusener ', 'SA)']
# ['Yuvraj Singh ', 'INDIA)']
# ['JO Holder ', 'WI)']
# ['Shoaib Malik ', 'PAK)']
# ['RC Russell ', 'ENG)']
# ['Salman Butt ', 'PAK)']
# ['PH Parfitt ', 'ENG)']
# ['N Dickwella ', 'SL)']
# ['GRJ Matthews ', 'AUS)']
# ['RA Jadeja ', 'INDIA)']
# ['BRM Taylor ', 'ZIM)']
# ['RES Wyatt ', 'ENG)']
# ['R Illingworth ', 'ENG)']
# ['RP Arnold ', 'SL)']
# ['IDS Smith ', 'NZ)']
# ['T Bavuma ', 'SA)']
# ['MD Marshall ', 'WI)']
# ['JP Crawley ', 'ENG)']
# ['DS Lehmann ', 'AUS)']
# ['Imrul Kayes ', 'BDESH)']
# ['NT Paranavitana ', 'SL)']
# ['MJ Horne ', 'NZ)']
# ['JDP Oram ', 'NZ)']
# ['BC Booth ', 'AUS)']
# ['DS Smith ', 'WI)']
# ['DM de Silva ', 'SL)']
# ['CJ Tavare ', 'ENG)']
# ['GA Faulkner ', 'SA)']
# ['WU Tharanga ', 'SL)']
# ['Javed Omar ', 'BDESH)']
# ['HH Dippenaar ', 'SA)']
# ['Shahid Afridi ', 'PAK)']
# ['JE Emburey ', 'ENG)']
# ['HM Nicholls ', 'NZ)']
# ['Babar Azam ', 'PAK)']
# ['VD Philander ', 'SA)']
# ['HMRKB Herath ', 'SL)']
# ['RL Chase ', 'WI)']
# ['GM Ritchie ', 'AUS)']
# ['KC Bland ', 'SA)']
# ['MH Denness ', 'ENG)']
# ['TG Southee ', 'NZ)']
# ['BC Broad ', 'ENG)']
# ['JT Tyldesley ', 'ENG)']
# ['J Darling ', 'AUS)']
# ['J Hardstaff jnr ', 'ENG)']
# ['MS Sinclair ', 'NZ)']
# ['WR Endean ', 'SA)']
# ['RB McCosker ', 'AUS)']
# ['SV Carlisle ', 'ZIM)']
# ['NJ Contractor ', 'INDIA)']
# ['Yashpal Sharma ', 'INDIA)']
# ['JJ Crowe ', 'NZ)']
# ['RT Robinson ', 'ENG)']
# ['M Prabhakar ', 'INDIA)']
# ['AP Sheahan ', 'AUS)']
# ['WA Brown ', 'AUS)']
# ['SM Patil ', 'INDIA)']
# ['SB Styris ', 'NZ)']
# ['RH Catterall ', 'SA)']
# ['T Taibu ', 'ZIM)']
# ['E Paynter ', 'ENG)']
# ['PJ Hughes ', 'AUS)']
# ['BF Hastings ', 'NZ)']
# ['KD Mackay ', 'AUS)']
# ['RR Lindwall ', 'AUS)']
# ['Qasim Umar ', 'PAK)']
# ['GS Ballance ', 'ENG)']
# ['SD Hope ', 'WI)']
# ['JM Parker ', 'NZ)']
# ['RW Barber ', 'ENG)']
# ['Intikhab Alam ', 'PAK)']
# ['MA Starc ', 'AUS)']
# ['Yasir Hameed ', 'PAK)']
# ['WB Phillips ', 'AUS)']
# ['AC Voges ', 'AUS)']
# ['DL Houghton ', 'ZIM)']
# ['A Symonds ', 'AUS)']
# ['B Lee ', 'AUS)']
# ['FJ Titmus ', 'ENG)']
# ['SO Dowrich ', 'WI)']
# ['JM Brearley ', 'ENG)']
# ['NR Mongia ', 'INDIA)']
# ['CEL Ambrose ', 'WI)']
# ['WAS Oldfield ', 'AUS)']
# ['AK Markram ', 'SA)']
# ['C Kelleway ', 'AUS)']
# ['AF Giles ', 'ENG)']
# ['MS Wade ', 'AUS)']
# ['Hon.FS Jackson ', 'ENG)']
# ['MW Goodwin ', 'ZIM)']
# ['RG Nadkarni ', 'INDIA)']
# ['Khaled Mashud ', 'BDESH)']
# ['HDRL Thirimanne ', 'SL)']
# ['RT Simpson ', 'ENG)']
# ['J Ryder ', 'AUS)']
# ['KLT Arthurton ', 'WI)']
# ['Rashid Latif ', 'PAK)']
# ['GP Swann ', 'ENG)']
# ['S Ramesh ', 'INDIA)']
# ['Wasim Bari ', 'PAK)']
# ['KG Viljoen ', 'SA)']
# ['J Blackwood ', 'WI)']
# ['J Dyson ', 'AUS)']
# ['DJ Richardson ', 'SA)']
# ['HL Collins ', 'AUS)']
# ['Javed Burki ', 'PAK)']
# ['BM Laird ', 'AUS)']
# ['L Vincent ', 'NZ)']
# ['OG Smith ', 'WI)']
# ['LRD Mendis ', 'SL)']
# ['AK Davidson ', 'AUS)']
# ['SS Das ', 'INDIA)']
# ['JS Solomon ', 'WI)']
# ['DJG Sammy ', 'WI)']
# ['JA Burns ', 'AUS)']
# ['RA Duff ', 'AUS)']
# ['N Boje ', 'SA)']
# ['G Fowler ', 'ENG)']
# ['DW Hookes ', 'AUS)']
# ['CA Davis ', 'WI)']
# ['BW Luckhurst ', 'ENG)']
# ['DR Jardine ', 'ENG)']
# ['JF Reid ', 'NZ)']
# ['TD Paine ', 'AUS)']
# ['RL Dias ', 'SL)']
# ['KS More ', 'INDIA)']
# ['JW Burke ', 'AUS)']
# ['A Shrewsbury snr ', 'ENG)']
# ['UC Hathurusingha ', 'SL)']
# ['JD Ryder ', 'NZ)']
# ['Shahriar Nafees ', 'BDESH)']
# ['V Pollard ', 'NZ)']
# ['RF Surti ', 'INDIA)']
# ['M Muralitharan ', 'ICC/SL)']
# ['MR Marsh ', 'AUS)']
# ['DW Steyn ', 'SA)']
# ['GE Gomez ', 'WI)']
# ['HB Cameron ', 'SA)']
# ['G Giffen ', 'AUS)']
# ['WP Saha ', 'INDIA)']
# ['Z Khan ', 'INDIA)']
# ['DG Phadkar ', 'INDIA)']
# ['DD Ebrahim ', 'ZIM)']
# ['CB Fry ', 'ENG)']
# ['S Wettimuny ', 'SL)']
# ['JN Gillespie ', 'AUS)']
# ['Haroon Rasheed ', 'PAK)']
# ['G Miller ', 'ENG)']
# ['VS Ransford ', 'AUS)']
# ['MDK Perera ', 'SL)']
# ['SA Durani ', 'INDIA)']
# ['DN Patel ', 'NZ)']
# ['MW Tate ', 'ENG)']
# ['AF Kippax ', 'AUS)']
# ['JHW Fingleton ', 'AUS)']
# ['M Labuschagne ', 'AUS)']
# ['CP Mead ', 'ENG)']
# ['P Willey ', 'ENG)']
# ['SC Williams ', 'WI)']
# ['JM Anderson ', 'ENG)']
# ['GS Ramchand ', 'INDIA)']
# ['MTG Elliott ', 'AUS)']
# ['GO Jones ', 'ENG)']
# ['Rev.DS Sheppard ', 'ENG)']
# ['R Edwards ', 'AUS)']
# ['MJ North ', 'AUS)']
# ['PM Siddle ', 'AUS)']
# ['RW Taylor ', 'ENG)']
# ['BW Sinclair ', 'NZ)']
# ['JM Gregory ', 'AUS)']
# ['CR Woakes ', 'ENG)']
# ['MG Vandort ', 'SL)']
# ['Rajin Saleh ', 'BDESH)']
# ['DT Lindsay ', 'SA)']
# ['MC Carew ', 'WI)']
# ['Faisal Iqbal ', 'PAK)']
# ['G Gunn ', 'ENG)']
# ['AC Bannerman ', 'AUS)']
# ['CC Lewis ', 'ENG)']
# ['IK Pathan ', 'INDIA)']
# ['BP Nash ', 'WI)']
# ['JA Raval ', 'NZ)']
# ['CJ Barnett ', 'ENG)']
# ['WG Grace ', 'ENG)']
# ['CB Wishart ', 'ZIM)']
# ['Alimuddin ', 'PAK)']
# ['Shan Masood ', 'PAK)']
# ['VG Kambli ', 'INDIA)']
# ['TM Head ', 'AUS)']
# ['AMJ Hilditch ', 'AUS)']
# ['SG Barnes ', 'AUS)']
# ['Waqar Hasan ', 'PAK)']
# ['JH Sinclair ', 'SA)']
# ['ED Solkar ', 'INDIA)']
# ['JKC Holt ', 'WI)']
# ['Mohammad Rafique ', 'BDESH)']
# ['RA Woolmer ', 'ENG)']
# ['Saleem Yousuf ', 'PAK)']
# ['C White ', 'ENG)']
# ['Sarfraz Nawaz ', 'PAK)']
# ['C de Grandhomme ', 'NZ)']
# ['Nasir Hossain ', 'BDESH)']
# ['S Madan Lal ', 'INDIA)']
# ['DR Flynn ', 'NZ)']
# ['MG Hughes ', 'AUS)']
# ['Abdul Qadir ', 'PAK)']
# ['RS Madugalle ', 'SL)']
# ['KD Karthik ', 'INDIA)']
# ['NM Lyon ', 'AUS)']
# ['GJ Rennie ', 'ZIM)']
# ['S Abid Ali ', 'INDIA)']
# ['AF Rae ', 'WI)']
# ['KJ Wadsworth ', 'NZ)']
# ['Waqar Younis ', 'PAK)']
# ['J Srinath ', 'INDIA)']
# ['SJ Snooke ', 'SA)']
# ['Umar Akmal ', 'PAK)']
# ['PV Simmons ', 'WI)']
# ['JG Bracewell ', 'NZ)']
# ['EJM Cowan ', 'AUS)']
# ['IWG Johnson ', 'AUS)']
# ['JM Taylor ', 'AUS)']
# ['AE Stoddart ', 'ENG)']
# ['KS Duleepsinhji ', 'ENG)']
# ['AV Mankad ', 'INDIA)']
# ['GE Tyldesley ', 'ENG)']
# ['KS Ranjitsinhji ', 'ENG)']
# ['LC Braund ', 'ENG)']
# ['KA Edwards ', 'WI)']
# ['R Subba Row ', 'ENG)']
# ['JW Zulch ', 'SA)']
# ['Ahmed Shehzad ', 'PAK)']
# ['BK Kunderan ', 'INDIA)']
# ['FS Trueman ', 'ENG)']
# ['RJ Burns ', 'ENG)']
# ['B Yardley ', 'AUS)']
# ['IJ Siedle ', 'SA)']
# ['BP Patel ', 'INDIA)']
# ['Junaid Siddique ', 'BDESH)']
# ['PG Fulton ', 'NZ)']
# ['JWHT Douglas ', 'ENG)']
# ['FCM Alexander ', 'WI)']
# ['SA Thomson ', 'NZ)']
# ['PS McDonnell ', 'AUS)']
# ['PR Reiffel ', 'AUS)']
# ['CA Roach ', 'WI)']
# ['G Ulyett ', 'ENG)']
# ['GD McKenzie ', 'AUS)']
# ['M Morkel ', 'SA)']
# ['CR Ervine ', 'ZIM)']
# ['CJ McDermott ', 'AUS)']
# ['DL Underwood ', 'ENG)']
# ['CA Walsh ', 'WI)']
# ['PAJ DeFreitas ', 'ENG)']
# ['PSP Handscomb ', 'AUS)']
# ['PA Patel ', 'INDIA)']
# ['MDKJ Perera ', 'SL)']
# ['Asif Mujtaba ', 'PAK)']
# ['BL Cairns ', 'NZ)']
# ['AH Kardar ', 'INDIA/PAK)']
# ['Saqlain Mushtaq ', 'PAK)']
# ['APF Chapman ', 'ENG)']
# ['DS Atkinson ', 'WI)']
# ['CM Spearman ', 'NZ)']
# ['GHS Trott ', 'AUS)']
# ['CWJ Athey ', 'ENG)']
# ['DA Allen ', 'ENG)']
# ['JR Murray ', 'WI)']
# ['KD Ghavri ', 'INDIA)']
# ['MA Holding ', 'WI)']
# ['CAG Russell ', 'ENG)']
# ['WL Murdoch ', 'AUS/ENG)']
# ['DK Lillee ', 'AUS)']
# ['AFA Lilley ', 'ENG)']
# ['PA Jaques ', 'AUS)']
# ['Azhar Mahmood ', 'PAK)']
# ['BR Taylor ', 'NZ)']
# ['GJ Cosier ', 'AUS)']
# ['RJ Christiani ', 'WI)']
# ['GF Lawson ', 'AUS)']
# ['A Melville ', 'SA)']
# ['PM Toohey ', 'AUS)']
# ['SN McGregor ', 'NZ)']
# ['ATW Grout ', 'AUS)']
# ['KAJ Roach ', 'WI)']
# ['DB Close ', 'ENG)']
# ['AM Blignaut ', 'ZIM)']
# ['JE Cheetham ', 'SA)']
# ['JDB Robertson ', 'ENG)']
# ['A Sandham ', 'ENG)']
# ['W Watson ', 'ENG)']
# ['L Amarnath ', 'INDIA)']
# ['PH Edmonds ', 'ENG)']
# ['H Carter ', 'AUS)']
# ['HR Adhikari ', 'INDIA)']
# ['MA Agarwal ', 'INDIA)']
# ['GC White ', 'SA)']
# ['HDPK Dharmasena ', 'SL)']
# ['BD Julien ', 'WI)']
# ['DG Cork ', 'ENG)']
# ['HJ Tayfield ', 'SA)']
# ['AR Caddick ', 'ENG)']
# ['GRJ Roope ', 'ENG)']
# ['JDC Goddard ', 'WI)']
# ['VM Merchant ', 'INDIA)']
# ['Basit Ali ', 'PAK)']
# ['JE Taylor ', 'WI)']
# ['D Gough ', 'ENG)']
# ['TG McIntosh ', 'NZ)']
# ['H Trumble ', 'AUS)']
# ['CM Old ', 'ENG)']
# ['RGD Willis ', 'ENG)']
# ['PA Strang ', 'ZIM)']
# ['SO Hetmyer ', 'WI)']
# ['AM Bacher ', 'SA)']
# ['RMH Binny ', 'INDIA)']
# ['TJ Franklin ', 'NZ)']
# ['KJ Funston ', 'SA)']
# ['SM Warnapura ', 'SL)']
# ['AJ Pithey ', 'SA)']
# ['WW Hall ', 'WI)']
# ['Sikandar Raza ', 'ZIM)']
# ['Soumya Sarkar ', 'BDESH)']
# ['Khurram Manzoor ', 'PAK)']
# ['J Briggs ', 'ENG)']
# ['AR MacGibbon ', 'NZ)']
# ['TR Veivers ', 'AUS)']
# ['BR Knight ', 'ENG)']
# ['NWD Yardley ', 'ENG)']
# ['AJ Watkins ', 'ENG)']
# ['TR Gripper ', 'ZIM)']
# ['JEC Franklin ', 'NZ)']
# ['FA Iredale ', 'AUS)']
# ['JR Ratnayeke ', 'SL)']
# ['JW Hearne ', 'ENG)']
# ['RAS Lakmal ', 'SL)']
# ['Wazir Mohammad ', 'PAK)']
# ['JM Blackham ', 'AUS)']
# ['Mashrafe Mortaza ', 'BDESH)']
# ['GH Hirst ', 'ENG)']
# ['GB Hole ', 'AUS)']
# ['PJ Sharpe ', 'ENG)']
# ['MG Bevan ', 'AUS)']
# ['PR Downton ', 'ENG)']
# ['CF Walters ', 'ENG)']
# ['W Mathias ', 'PAK)']
# ['Mohammad Wasim ', 'PAK)']
# ['SFAF Bacchus ', 'WI)']
# ['KK Jennings ', 'ENG)']
# ['WK Lees ', 'NZ)']
# ['CZ Harris ', 'NZ)']
# ['NRD Compton ', 'ENG)']
# ['RWT Key ', 'ENG)']
# ['JM How ', 'NZ)']
# ['JA Snow ', 'ENG)']
# ['DAJ Holford ', 'WI)']
# ['SK Raina ', 'INDIA)']
# ['A Turner ', 'AUS)']
# ['AME Roberts ', 'WI)']
# ['AJ Hall ', 'SA)']
# ['Sami Aslam ', 'PAK)']
# ['LE Favell ', 'AUS)']
# ['HD Rutherford ', 'NZ)']
# ['RR Pant ', 'INDIA)']
# ['Mohammad Amir ', 'PAK)']
# ['GOB Allen ', 'ENG)']
# ['S Venkataraghavan ', 'INDIA)']
# ['Nasim-ul-Ghani ', 'PAK)']
# ['R Abel ', 'ENG)']
# ['Haris Sohail ', 'PAK)']
# ['Liton Das ', 'BDESH)']
# ['SJ Harmison ', 'ENG/ICC)']
# ['GAR Lock ', 'ENG)']
# ['MJ Santner ', 'NZ)']
# ['PL Symcox ', 'SA)']
# ['RS Modi ', 'INDIA)']
# ['EAS Prasanna ', 'INDIA)']
# ['FR Brown ', 'ENG)']
# ['RW Morgan ', 'NZ)']
# ['JJ Lyons ', 'AUS)']
# ['J Arun Lal ', 'INDIA)']
# ['MD Bell ', 'NZ)']
# ['DJ Nash ', 'NZ)']
# ['W Barnes ', 'ENG)']
# ['N Deonarine ', 'WI)']
# ['DJ Malan ', 'ENG)']
# ['CB van Ryneveld ', 'SA)']
# ['CS Dempster ', 'NZ)']
# ['WW Read ', 'ENG)']
# ['NV Knight ', 'ENG)']
# ['Asim Kamal ', 'PAK)']
# ['AV Bedser ', 'ENG)']
# ['RG Archer ', 'AUS)']
# ['DG Brownlie ', 'NZ)']
# ['JDS Neesham ', 'NZ)']
# ['D Bishoo ', 'WI)']
# ['VY Richardson ', 'AUS)']
# ['I Sharma ', 'INDIA)']
# ['W Bruce ', 'AUS)']
# ['ARS Silva ', 'SL)']
# ['Yasir Shah ', 'PAK)']
# ['EJG Morgan ', 'ENG)']
# ['M Ntini ', 'SA)']
# ['EL Dalton ', 'SA)']
# ['WM Darling ', 'AUS)']
# ['DR Pringle ', 'ENG)']
# ['IC Davis ', 'AUS)']
# ['Hanumant Singh ', 'INDIA)']
# ['Al Sahariar ', 'BDESH)']
# ['CJ Anderson ', 'NZ)']
# ['FL Fane ', 'ENG)']
# ['VA Holder ', 'WI)']
# ['A Bacher ', 'SA)']
# ['JR Thomson ', 'AUS)']
# ['RW Chakabva ', 'ZIM)']
# ['JC Laker ', 'ENG)']
# ['JB Statham ', 'ENG)']
# ['DS Steele ', 'ENG)']
# ['J Garner ', 'WI)']
# ['H Verity ', 'ENG)']
# ['BA Pocock ', 'NZ)']
# ['JJ Kelly ', 'AUS)']
# ['DPB Morkel ', 'SA)']
# ['Hannan Sarkar ', 'BDESH)']
# ['AB Barath ', 'WI)']
# ['KD Boyce ', 'WI)']
# ['W Bates ', 'ENG)']
# ['BS Bedi ', 'INDIA)']
# ['JFM Morrison ', 'NZ)']
# ['Mushtaq Ahmed ', 'PAK)']
# ['Mansoor Akhtar ', 'PAK)']
# ['C Milburn ', 'ENG)']
# ['JH Wardle ', 'ENG)']
# ['AA Donald ', 'SA)']
# ['HJH Marshall ', 'NZ)']
# ['JL Denly ', 'ENG)']
# ['A Mishra ', 'INDIA)']
# ["KJ O'Keeffe ", 'AUS)']
# ['GD McGrath ', 'AUS)']
# ['GS Camacho ', 'WI)']
# ['PJ Cummins ', 'AUS)']
# ['AFG Griffith ', 'WI)']
# ['Mehidy Hasan Miraz ', 'BDESH)']
# ['MT Renshaw ', 'AUS)']
# ['LN Constantine ', 'WI)']
# ['IR Bishop ', 'WI)']
# ['SC Cook ', 'SA)']
# ['HG Deane ', 'SA)']
# ['RG Twose ', 'NZ)']
# ['PN Kirsten ', 'SA)']
# ['TW Jarvis ', 'NZ)']
# ['M Kaif ', 'INDIA)']
# ['PF Warner ', 'ENG)']
# ['Fazal Mahmood ', 'PAK)']
# ['JAJ Christy ', 'SA)']
# ['UDU Chandana ', 'SL)']
# ['TA Boult ', 'NZ)']
# ['TMK Mawoyo ', 'ZIM)']
# ['RC Motz ', 'NZ)']
# ['S Mushtaq Ali ', 'INDIA)']
# ['RWV Robins ', 'ENG)']
# ['JC Watkins ', 'SA)']
# ['CS Baugh ', 'WI)']
# ['SM Curran ', 'ENG)']
# ['PM Pollock ', 'SA)']
# ['JT Ikin ', 'ENG)']
# ['RJ Harris ', 'AUS)']
# ['RE Foster ', 'ENG)']
# ['DA Murray ', 'WI)']
# ['AG Steel ', 'ENG)']
# ['BAG Murray ', 'NZ)']
# ['TJE Andrews ', 'AUS)']
# ['Adnan Akmal ', 'PAK)']
# ['RG Barlow ', 'ENG)']
# ['HR Lance ', 'SA)']
# ['V Sibanda ', 'ZIM)']
# ['MD Craig ', 'NZ)']
# ['K Rabada ', 'SA)']
# ['MHN Walker ', 'AUS)']
# ['Alok Kapali ', 'BDESH)']
# ['Aftab Ahmed ', 'BDESH)']
# ['MP Donnelly ', 'NZ)']
# ['PA Gibb ', 'ENG)']
# ['MLC Foster ', 'WI)']
# ['Umar Gul ', 'PAK)']
# ['MN Waller ', 'ZIM)']
# ['A Jadeja ', 'INDIA)']
# ['RS Bopara ', 'ENG)']
# ['TT Bresnan ', 'ENG)']
# ['AD Hales ', 'ENG)']
# ['CE McLeod ', 'AUS)']
# ['RS Morton ', 'WI)']
# ['AB Agarkar ', 'INDIA)']
# ['SB Doull ', 'NZ)']
# ['E Chigumbura ', 'ZIM)']
# ['GL Jessop ', 'ENG)']
# ['DAJ Bracewell ', 'NZ)']
# ['KA Maharaj ', 'SA)']
# ['Aamer Malik ', 'PAK)']
# ['EDAS McMorris ', 'WI)']
# ['GO Rabone ', 'NZ)']
# ['CV Grimmett ', 'AUS)']
# ['MF Maharoof ', 'SL)']
# ['GP Wickramasinghe ', 'SL)']
# ['SJE Loxton ', 'AUS)']
# ['N Wagner ', 'NZ)']
# ['SC Williams ', 'ZIM)']
# ['AG Chipperfield ', 'AUS)']
# ['B Kumar ', 'INDIA)']
# ['D Lloyd ', 'ENG)']
# ['S Amarnath ', 'INDIA)']
# ['M Dillon ', 'WI)']
# ['Iqbal Qasim ', 'PAK)']
# ['JM Vince ', 'ENG)']
# ['CB Llewellyn ', 'SA)']
# ['Shoaib Akhtar ', 'PAK)']
# ['WA Hadlee ', 'NZ)']
# ['ML Apte ', 'INDIA)']
# ['AG Cremer ', 'ZIM)']
# ['AU Rashid ', 'ENG)']
# ['LPC Silva ', 'SL)']
# ['RA Harper ', 'WI)']
# ['RO Collinge ', 'NZ)']
# ['PJ Moor ', 'ZIM)']
# ['PL van der Merwe ', 'SA)']
# ['NC Johnson ', 'ZIM)']
# ['HH Pandya ', 'INDIA)']
# ['S Ranatunga ', 'SL)']
# ['Aminul Islam ', 'BDESH)']
# ['CC Griffith ', 'WI)']
# ['DR Hadlee ', 'NZ)']
# ['LJ Tancred ', 'SA)']
# ['MD Stoneman ', 'ENG)']
# ['CL Vincent ', 'SA)']
# ['CS Serjeant ', 'AUS)']
# ['GR Dilley ', 'ENG)']
# ['Shahadat Hossain ', 'BDESH)']
# ['Nafees Iqbal ', 'BDESH)']
# ['GJ Bonnor ', 'AUS)']
# ['WW Wade ', 'SA)']
# ['WH Scotton ', 'ENG)']
# ['AJY Hopkins ', 'AUS)']
# ['BA Richards ', 'SA)']
# ['Maqsood Ahmed ', 'PAK)']
# ['JT Murray ', 'ENG)']
# ['RO Hinds ', 'WI)']
# ['BJ Hodge ', 'AUS)']
# ['BK Shepherd ', 'AUS)']
# ['Taslim Arif ', 'PAK)']
# ['ME Chapple ', 'NZ)']
# ['JB Bolus ', 'ENG)']
# ['W Larkins ', 'ENG)']
# ['ML Page ', 'NZ)']
# ['LR Gibbs ', 'WI)']
# ['Mohammad Sami ', 'PAK)']
# ['A Ward ', 'ENG)']
# ['SJ Benn ', 'WI)']
# ['FR Martin ', 'WI)']
# ['Imam-ul-Haq ', 'PAK)']
# ['H Larwood ', 'ENG)']
# ['CE Pellew ', 'AUS)']
# ['GJ Gilmour ', 'AUS)']
# ['PR Sleep ', 'AUS)']
# ['CT Radley ', 'ENG)']
# ['Sabbir Rahman ', 'BDESH)']
# ['RH Spooner ', 'ENG)']
# ['BW Yuile ', 'NZ)']
# ['JED Sealy ', 'WI)']
# ['J Worrall ', 'AUS)']
# ['KTGD Prasad ', 'SL)']
# ['LS Darling ', 'AUS)']
# ['A Jackson ', 'AUS)']
# ['MJ Hoggard ', 'ENG)']
# ['TP Horan ', 'AUS)']
# ['SB Bangar ', 'INDIA)']
# ['WKM Benjamin ', 'WI)']
# ['JT Brown ', 'ENG)']
# ['JN Crawford ', 'ENG)']
# ['AB Williams ', 'WI)']
# ['PM Nevill ', 'AUS)']
# ['GH Vihari ', 'INDIA)']
# ['BC Strang ', 'ZIM)']
# ['RJ Peterson ', 'SA)']
# ['JM Read ', 'ENG)']
# ['PL Harris ', 'SA)']
# ['PGV van der Bijl ', 'SA)']
# ['CL McCool ', 'AUS)']
# ['TA Ward ', 'SA)']
# ['VJ Scott ', 'NZ)']
# ['A Cotter ', 'AUS)']
# ['AR Lewis ', 'ENG)']
# ['TE Blain ', 'NZ)']
# ['TM Moody ', 'AUS)']
# ['JM Blanckenberg ', 'SA)']
# ['DAS Gunaratne ', 'SL)']
# ['MD Moxon ', 'ENG)']
# ['BH Pairaudeau ', 'WI)']
# ['BH Valentine ', 'ENG)']
# ['B Wood ', 'ENG)']
# ['Mohammed Shami ', 'INDIA)']
# ['Saeed Ajmal ', 'PAK)']
# ['MA Vermeulen ', 'ZIM)']
# ['WV Raman ', 'INDIA)']
# ['IS Sodhi ', 'NZ)']
# ['TR Ambrose ', 'ENG)']
# ['TJ Friend ', 'ZIM)']
# ['JL Hendriks ', 'WI)']
# ['CT Bancroft ', 'AUS)']
# ['NA Foster ', 'ENG)']
# ['RJ Bright ', 'AUS)']
# ['MS Kasprowicz ', 'AUS)']
# ['CD Cumming ', 'NZ)']
# ['Mohammad Ilyas ', 'PAK)']
# ['JW Guy ', 'NZ)']
# ['RM Hogg ', 'AUS)']
# ['WM Wallace ', 'NZ)']
# ['A Chopra ', 'INDIA)']
# ['Saleem Elahi ', 'PAK)']
# ['RJ Ratnayake ', 'SL)']
# ['PL Taylor ', 'AUS)']
# ['AA Mallett ', 'AUS)']
# ['AA Baig ', 'INDIA)']
# ['TB de Bruyn ', 'SA)']
# ['SP Jones ', 'AUS)']
# ['Imran Nazir ', 'PAK)']
# ['R Peel ', 'ENG)']
# ['PW Sherwell ', 'SA)']
# ['DR Tuffey ', 'NZ)']
# ['NM Hauritz ', 'AUS)']
# ['DT Ring ', 'AUS)']
# ['PK Amre ', 'INDIA)']
# ['D Denton ', 'ENG)']
# ['RW Anderson ', 'NZ)']
# ['AG Kripal Singh ', 'INDIA)']
# ['GG Arnold ', 'ENG)']
# ['RDB Croft ', 'ENG)']
# ['HG Vivian ', 'NZ)']
# ['RB Desai ', 'INDIA)']
# ['CK Kapugedera ', 'SL)']
# ['CL King ', 'WI)']
# ['Naeem Islam ', 'BDESH)']
# ['AE Relf ', 'ENG)']
# ['GL Weir ', 'NZ)']
# ['JL Pattinson ', 'AUS)']
# ['GC Grant ', 'WI)']
# ['AG Fairfax ', 'AUS)']
# ["WJ O'Reilly ", 'AUS)']
# ['AH Bakewell ', 'ENG)']
# ['DJ Insole ', 'ENG)']
# ['DBL Powell ', 'WI)']
# ['DS de Silva ', 'SL)']
# ['JH Hampshire ', 'ENG)']
# ['LR Johnson ', 'WI)']
# ['AJ Richardson ', 'AUS)']
# ['NS Yadav ', 'INDIA)']
# ['JR Hazlewood ', 'AUS)']
# ['TL Best ', 'WI)']
# ['KE Rigg ', 'AUS)']
# ['BN Jarman ', 'AUS)']
# ['NBF Mann ', 'SA)']
# ['M van Jaarsveld ', 'SA)']
# ['C Sharma ', 'INDIA)']
# ['Abdur Rehman ', 'PAK)']
# ['JW Gleeson ', 'AUS)']
# ['Shujauddin ', 'PAK)']
# ['S van Zyl ', 'SA)']
# ['JEF Beck ', 'NZ)']
# ['FH Edwards ', 'WI)']
# ['SJ Rixon ', 'AUS)']
# ['D Tallon ', 'AUS)']
# ['W Gunn ', 'ENG)']
# ['CL Smith ', 'ENG)']
# ['KMDN Kulasekara ', 'SL)']
# ['RB Minnett ', 'AUS)']
# ['ARC Fraser ', 'ENG)']
# ['CO Browne ', 'WI)']
# ['VC Drakes ', 'WI)']
# ['MS Harris ', 'AUS)']
# ['J Mubarak ', 'SL)']
# ['MJ Stewart ', 'ENG)']
# ['Tapash Baisya ', 'BDESH)']
# ['EE Hemmings ', 'ENG)']
# ['J Moroney ', 'AUS)']
# ['LK Germon ', 'NZ)']
# ['DR Parry ', 'WI)']
# ['JS Patel ', 'NZ)']
# ['PGH Fender ', 'ENG)']
# ['RIC Holder ', 'WI)']
# ['DK Morrison ', 'NZ)']
# ['S Shivnarine ', 'WI)']
# ['PGZ Harris ', 'NZ)']
# ['GN Edwards ', 'NZ)']
# ['FG Mann ', 'ENG)']
# ['DJ Capel ', 'ENG)']
# ['GRA Langley ', 'AUS)']
# ['KK Nair ', 'INDIA)']
# ['RO Schwarz ', 'SA)']
# ['Taijul Islam ', 'BDESH)']
# ['WGA Parkhouse ', 'ENG)']
# ['RG Samuels ', 'WI)']
# ['AE Dick ', 'NZ)']
# ['Talat Ali ', 'PAK)']
# ['KDK Vithanage ', 'SL)']
# ['NAM McLean ', 'WI)']
# ['IDK Salisbury ', 'ENG)']
# ['PJ Wiseman ', 'NZ)']
# ['NJN Hawke ', 'AUS)']
# ['WE Russell ', 'ENG)']
# ['S Ramadhin ', 'WI)']
# ['PR Adams ', 'SA)']
# ['Danish Kaneria ', 'PAK)']
# ['CMW Read ', 'ENG)']
# ['PS de Villiers ', 'SA)']
# ['HJH Scott ', 'AUS)']
# ['ID Craig ', 'AUS)']
# ['BC Rose ', 'ENG)']
# ['P Holmes ', 'ENG)']
# ['SJ Pegler ', 'SA)']
# ['AJ Bichel ', 'AUS)']
# ['JMM Commaille ', 'SA)']
# ['BW Hilfenhaus ', 'AUS)']
# ['PNF Mansell ', 'SA)']
# ['MS Nichols ', 'ENG)']
# ['MB Poore ', 'NZ)']
# ['WA Shalders ', 'SA)']
# ['RT Spooner ', 'ENG)']
# ['MN Hart ', 'NZ)']
# ['BL Irvine ', 'SA)']
# ['SAR Silva ', 'SL)']
# ['HB Taber ', 'AUS)']
# ['SB Joshi ', 'INDIA)']
# ['JG Leggat ', 'NZ)']
# ['S Matsikenyeri ', 'ZIM)']
# ['DK Gaekwad ', 'INDIA)']
# ['P Lever ', 'ENG)']
# ['CK Nayudu ', 'INDIA)']
# ['SCG MacGill ', 'AUS)']
# ['CR Matthews ', 'SA)']
# ['EP Nupen ', 'SA)']
# ['Jahurul Islam ', 'BDESH)']
# ['LSM Miller ', 'NZ)']
# ['MA Carberry ', 'ENG)']
# ['EW Freeman ', 'AUS)']
# ['Rizwan-uz-Zaman ', 'PAK)']
# ['Sanwar Hossain ', 'BDESH)']
# ['Lord Tennyson ', 'ENG)']
# ['D Dasgupta ', 'INDIA)']
# ['FA Rose ', 'WI)']
# ['LA Stricker ', 'SA)']
# ['TM Dowlin ', 'WI)']
# ['FLH Mooney ', 'NZ)']
# ['CA Best ', 'WI)']
# ['DJ Brown ', 'ENG)']
# ['KL Hutchings ', 'ENG)']
# ['CFK van Wyk ', 'NZ)']
# ['AEE Vogler ', 'SA)']
# ['TW Garrett ', 'AUS)']
# ['GJ Maxwell ', 'AUS)']
# ['UT Yadav ', 'INDIA)']
# ['A Nel ', 'SA)']
# ['Mahmood Hussain ', 'PAK)']
# ['Raqibul Hasan ', 'BDESH)']
# ['SD Robson ', 'ENG)']
# ['HSTL Hendry ', 'AUS)']
# ['R Rampaul ', 'WI)']
# ['MH Dekker ', 'ZIM)']
# ['BT Foakes ', 'ENG)']
# ['RC Blunt ', 'NZ)']
# ['FR Foster ', 'ENG)']
# ['VL Mehra ', 'INDIA)']
# ['Wajahatullah Wasti ', 'PAK)']
# ['AM Moir ', 'NZ)']
# ['MC Snedden ', 'NZ)']
# ['HF Wade ', 'SA)']
# ['ALF de Mel ', 'SL)']
# ['GM Fullerton ', 'SA)']
# ['CMH Hathorn ', 'SA)']
# ['AJ Redmond ', 'NZ)']
# ['Sohag Gazi ', 'BDESH)']
# ['G Thomas ', 'AUS)']
# ['CTB Turner ', 'AUS)']
# ['Abid Ali ', 'PAK)']
# ['TS Worthington ', 'ENG)']
# ['DSBP Kuruppu ', 'SL)']
# ['A Mukund ', 'INDIA)']
# ['DR Smith ', 'WI)']
# ['JF Crapp ', 'ENG)']
# ['L Ronchi ', 'NZ)']
# ['OAC Banks ', 'WI)']
# ['HJ Keith ', 'SA)']
# ['Tauseef Ahmed ', 'PAK)']
# ['RJ Sidebottom ', 'ENG)']
# ['JWA Taylor ', 'ENG)']
# ['J Hardstaff snr ', 'ENG)']
# ['BN French ', 'ENG)']
# ['W Voce ', 'ENG)']
# ['JK Lever ', 'ENG)']
# ['Q McMillan ', 'SA)']
# ['Wahab Riaz ', 'PAK)']
# ['DW Fleming ', 'AUS)']
# ['Shamsur Rahman ', 'BDESH)']
# ['BR Hartland ', 'NZ)']
# ['AH Jarvis ', 'AUS)']
# ['DJ Murray ', 'NZ)']
# ['KJ Arnott ', 'ZIM)']
# ['H Graham ', 'AUS)']
# ['PAM Hands ', 'SA)']
# ['Tahir Naqqash ', 'PAK)']
# ['G Brown ', 'ENG)']
# ['MD Gunathilaka ', 'SL)']
# ['GB Legge ', 'ENG)']
# ['JD Campbell ', 'WI)']
# ['ACB Langton ', 'SA)']
# ['A Mitchell ', 'ENG)']
# ['Rahmat Shah ', 'AFG)']
# ['TAM Siriwardana ', 'SL)']
# ["S O'Linn ", 'SA)']
# ['N Phillip ', 'WI)']
# ['MA Wood ', 'ENG)']
# ['GE Palmer ', 'AUS)']
# ['RS Cunis ', 'NZ)']
# ['RS Kalpage ', 'SL)']
# ['SJ Rhodes ', 'ENG)']
# ['OC Dawson ', 'SA)']
# ['DF Whatmore ', 'AUS)']
# ['L Amar Singh ', 'INDIA)']
# ['HJ Howarth ', 'NZ)']
# ['AO Jones ', 'ENG)']
# ['AMB Rowan ', 'SA)']
# ['KD Mills ', 'NZ)']
# ['ARA Murray ', 'SA)']
# ['DVP Wright ', 'ENG)']
# ['Zahid Fazal ', 'PAK)']
# ['DNT Zoysa ', 'SL)']
# ['PT Barton ', 'NZ)']
# ['CJ Richards ', 'ENG)']
# ['CB Lambert ', 'WI)']
# ['FT Mann ', 'ENG)']
# ['S Sreesanth ', 'INDIA)']
# ['JM Wiener ', 'AUS)']
# ['MC Bird ', 'ENG)']
# ['ST Finn ', 'ENG)']
# ['Ijaz Butt ', 'PAK)']
# ['JWH Makepeace ', 'ENG)']
# ['PA Wallace ', 'WI)']
# ['AJ Finch ', 'AUS)']
# ['LMP Simmons ', 'WI)']
# ['GR Stead ', 'NZ)']
# ['BOP Fernando ', 'SL)']
# ['Nazar Mohammad ', 'PAK)']
# ['IM Barrow ', 'WI)']
# ['Saleem Altaf ', 'PAK)']
# ['SL Malinga ', 'SL)']
# ['Shadman Islam ', 'BDESH)']
# ['WA Johnston ', 'AUS)']
# ['GJ Thompson ', 'ENG)']
# ['Abdul Kadir ', 'PAK)']
# ['JC Alabaster ', 'NZ)']
# ['TA Blundell ', 'NZ)']
# ['WE Midwinter ', 'AUS/ENG)']
# ['OA Shah ', 'ENG)']
# ['MJ Susskind ', 'SA)']
# ['Khaled Mahmud ', 'BDESH)']
# ['S Shillingford ', 'WI)']
# ['A Lyth ', 'ENG)']
# ['MJF Shrimpton ', 'NZ)']
# ['GA Bartlett ', 'NZ)']
# ['GC Small ', 'ENG)']
# ['GTS Stevens ', 'ENG)']
# ['V Subramanya ', 'INDIA)']
# ['SM Ervine ', 'ZIM)']
# ['RW Price ', 'ZIM)']
# ['AN Connolly ', 'AUS)']
# ['RG Hart ', 'NZ)']
# ['Akram Khan ', 'BDESH)']
# ['DM Lewis ', 'WI)']
# ['Rubel Hossain ', 'BDESH)']
# ["KJ O'Brien ", 'IRE)']
# ['EC Petrie ', 'NZ)']
# ['Arshad Ayub ', 'INDIA)']
# ['Manjural Islam Rana ', 'BDESH)']
# ['DM Wellham ', 'AUS)']
# ['J Selby ', 'ENG)']
# ['BB Chari ', 'ZIM)']
# ['Dilawar Hussain ', 'INDIA)']
# ['W Flowers ', 'ENG)']
# ['HV Hordern ', 'AUS)']
# ['ADG Roberts ', 'NZ)']
# ['R Swetman ', 'ENG)']
# ['Khalid Ibadulla ', 'PAK)']
# ['EH Bowley ', 'ENG)']
# ['TB Burtt ', 'NZ)']
# ['NF Druce ', 'ENG)']
# ['CM Francois ', 'SA)']
# ['PA McAlister ', 'AUS)']
# ['HGO Owen-Smith ', 'SA)']
# ['Sohail Khan ', 'PAK)']
# ['AJL Hill ', 'ENG)']
# ['Fawad Alam ', 'PAK)']
# ['Asghar Afghan ', 'AFG)']
# ['CRD Fernando ', 'SL)']
# ['G Geary ', 'ENG)']
# ['VJ Marks ', 'ENG)']
# ['HH Massie ', 'AUS)']
# ['Abdur Razzak ', 'BDESH)']
# ['SR Clark ', 'AUS)']
# ['EJ Gray ', 'NZ)']
# ['AW Roberts ', 'NZ)']
# ['MHW Papps ', 'NZ)']
# ['TJ Zoehrer ', 'AUS)']
# ['BA Davis ', 'WI)']
# ['RB Kenny ', 'INDIA)']
# ['FA Lowson ', 'ENG)']
# ['RK Nunes ', 'WI)']
# ['FC Hayes ', 'ENG)']
# ['Shuvagata Hom ', 'BDESH)']
# ['XM Marshall ', 'WI)']
# ['Mehrab Hossain jnr ', 'BDESH)']
# ['JB Mortimore ', 'ENG)']
# ['JW Trumble ', 'AUS)']
# ['Ali Naqvi ', 'PAK)']
# ['SF Barnes ', 'ENG)']
# ['CD Gopinath ', 'INDIA)']
# ['James Langridge ', 'ENG)']
# ['D Williams ', 'WI)']
# ['Mehrab Hossain ', 'BDESH)']
# ['JE Mills ', 'NZ)']
# ['SLV Raju ', 'INDIA)']
# ['Shadab Khan ', 'PAK)']
# ['C Bannerman ', 'AUS)']
# ['Naved-ul-Hasan ', 'PAK)']
# ['JC White ', 'ENG)']
# ['LE Plunkett ', 'ENG)']
# ['AW Carr ', 'ENG)']
# ['PP Shaw ', 'INDIA)']
# ['FB Smith ', 'NZ)']
# ['S Wazir Ali ', 'INDIA)']
# ['G Dymock ', 'AUS)']
# ['CN Frank ', 'SA)']
# ['DE Malcolm ', 'ENG)']
# ['PT Collins ', 'WI)']
# ['Hasan Raza ', 'PAK)']
# ['KA Archer ', 'AUS)']
# ['G Duckworth ', 'ENG)']
# ['EAE Baptiste ', 'WI)']
# ['R Kilner ', 'ENG)']
# ['ML Love ', 'AUS)']
# ['FI de Caires ', 'WI)']
# ['Mushfiqur Rahman ', 'BDESH)']
# ['WH Lockwood ', 'ENG)']
# ['H Strudwick ', 'ENG)']
# ['FH Tyson ', 'ENG)']
# ['Ashraf Ali ', 'PAK)']
# ['HB Cave ', 'NZ)']
# ['JM Ghorpade ', 'INDIA)']
# ['NS Harford ', 'NZ)']
# ['JT Sparling ', 'NZ)']
# ['AJ Tudor ', 'ENG)']
# ['Mohammad Mithun ', 'BDESH)']
# ['WG Quaife ', 'ENG)']
# ['AE Trott ', 'AUS/ENG)']
# ['J Yadav ', 'INDIA)']
# ['DT Tiripano ', 'ZIM)']
# ['JS Foster ', 'ENG)']
# ['AO Malhotra ', 'INDIA)']
# ['MJ Procter ', 'SA)']
# ['TBA May ', 'AUS)']
# ['D Mohammed ', 'WI)']
# ['NS Tamhane ', 'INDIA)']
# ['MJL Turnbull ', 'ENG)']
# ['J Benaud ', 'AUS)']
# ['TC Lowry ', 'NZ)']
# ['KCG Benjamin ', 'WI)']
# ['AE Greenidge ', 'WI)']
# ['AA Mailey ', 'AUS)']
# ['CW Smith ', 'WI)']
# ['WS Farrer ', 'SA)']
# ['DRA Gehrs ', 'AUS)']
# ['MJ Henry ', 'NZ)']
# ['Shafqat Rana ', 'PAK)']
# ['RS Grant ', 'WI)']
# ['MJ Leach ', 'ENG)']
# ['MS Panesar ', 'ENG)']
# ['NH Fairbrother ', 'ENG)']
# ['H Hameed ', 'ENG)']
# ['RA Hutton ', 'ENG)']
# ['RT Latham ', 'NZ)']
# ["IE O'Brien ", 'NZ)']
# ['KJ Wright ', 'AUS)']
# ['OE Wynne ', 'SA)']
# ['JAH Marshall ', 'NZ)']
# ['IT Shillingford ', 'WI)']
# ['UWMBCA Welegedara ', 'SL)']
# ['R Mutumbami ', 'ZIM)']
# ['FR Spofforth ', 'AUS)']
# ['Mohammad Rizwan ', 'PAK)']
# ['W Storer ', 'ENG)']
# ['JA Jameson ', 'ENG)']
# ['JW Martin ', 'AUS)']
# ['BS Sandhu ', 'INDIA)']
# ['PJW Allott ', 'ENG)']
# ['GA Lohmann ', 'ENG)']
# ['BAW Mendis ', 'SL)']
# ['TM Findlay ', 'WI)']
# ['JL Kerr ', 'NZ)']
# ["LPJ O'Brien ", 'AUS)']
# ['DP Samaraweera ', 'SL)']
# ['Shafiul Islam ', 'BDESH)']
# ['MA Ealham ', 'ENG)']
# ['Naimur Rahman ', 'BDESH)']
# ['K Cranston ', 'ENG)']
# ['AER Gilligan ', 'ENG)']
# ['GA Greenidge ', 'WI)']
# ['PS Heine ', 'SA)']
# ['WW Whysall ', 'ENG)']
# ['TJ Jenner ', 'AUS)']
# ['VWC Jupp ', 'ENG)']
# ['CT Sarwate ', 'INDIA)']
# ['KJ Barnett ', 'ENG)']
# ['SL Boock ', 'NZ)']
# ['PG Joshi ', 'INDIA)']
# ['RH Vance ', 'NZ)']
# ['MRJ Veletta ', 'AUS)']
# ["SP O'Donnell ", 'AUS)']
# ['PI Pocock ', 'ENG)']
# ['Gul Mohammad ', 'INDIA/PAK)']
# ['TG Hogan ', 'AUS)']
# ['SP Jones ', 'ENG)']
# ['DJ Gandhi ', 'INDIA)']
# ['CA Milton ', 'ENG)']
# ['H Wood ', 'ENG)']
# ['TM Alderman ', 'AUS)']
# ['G Cook ', 'ENG)']
# ['NLTC Perera ', 'SL)']
# ['BKV Prasad ', 'INDIA)']
# ['DE Bernard ', 'WI)']
# ['W Brockwell ', 'ENG)']
# ['WW Davis ', 'WI)']
# ['AIC Dodemaide ', 'AUS)']
# ['RM Ellison ', 'ENG)']
# ['SC Guillen ', 'NZ/WI)']
# ['CA McWatt ', 'WI)']
# ['A McGrath ', 'ENG)']
# ['T Panyangara ', 'ZIM)']
# ['JTC Vaughan ', 'NZ)']
# ['W Ferguson ', 'WI)']
# ['ST Gabriel ', 'WI)']
# ['Zulfiqar Ahmed ', 'PAK)']
# ['Nawab of Pataudi snr ', 'ENG/INDIA)']
# ['RO Jenkins ', 'ENG)']
# ['H Moses ', 'AUS)']
# ['CD Collymore ', 'WI)']
# ['PB Dassanayake ', 'SL)']
# ['FJ Laver ', 'AUS)']
# ['AC Agar ', 'AUS)']
# ['BA Barnett ', 'AUS)']
# ['STR Binny ', 'INDIA)']
# ['Shahid Nazir ', 'PAK)']
# ['RMS Eranga ', 'SL)']
# ['SG Gedye ', 'NZ)']
# ['T Westley ', 'ENG)']
# ['Fakhar Zaman ', 'PAK)']
# ['Ghulam Ahmed ', 'INDIA)']
# ['D Kenyon ', 'ENG)']
# ['AJ Doolan ', 'AUS)']
# ['WE Astill ', 'ENG)']
# ['PR Carlstein ', 'SA)']
# ['RW Blair ', 'NZ)']
# ['AL Mann ', 'AUS)']
# ['EA Halliwell ', 'SA)']
# ['J Sharp ', 'ENG)']
# ['CC Depeiaza ', 'WI)']
# ['ML Nkala ', 'ZIM)']
# ['JJ Roy ', 'ENG)']
# ['PH Sharma ', 'INDIA)']
# ['DW Headley ', 'ENG)']
# ['GB Hogg ', 'AUS)']
# ['DA Marillier ', 'ZIM)']
# ['PL Winslow ', 'SA)']
# ['EAR de Silva ', 'SL)']
# ['K Higgs ', 'ENG)']
# ['MV Nagamootoo ', 'WI)']
# ['L Baichan ', 'WI)']
# ['HK Olonga ', 'ZIM)']
# ['GJ Bailey ', 'AUS)']
# ['C Blythe ', 'ENG)']
# ['SP Gupte ', 'INDIA)']
# ['Ijaz Faqih ', 'PAK)']
# ['Aftab Gul ', 'PAK)']
# ['LJ Moon ', 'ENG)']
# ['CR Brathwaite ', 'WI)']
# ['CP Carter ', 'SA)']
# ['DA Gunawardene ', 'SL)']
# ['RH Shodhan ', 'INDIA)']
# ['EJ Chatfield ', 'NZ)']
# ['Enamul Haque ', 'BDESH)']
# ['CJ Jordan ', 'ENG)']
# ['NGB Cook ', 'ENG)']
# ['N Gifford ', 'ENG)']
# ['JFW Nicolson ', 'SA)']
# ['AD Ogilvie ', 'AUS)']
# ['HM Goonatilleke ', 'SL)']
# ['LV Maddocks ', 'AUS)']
# ['T Richardson ', 'ENG)']
# ['Younis Ahmed ', 'PAK)']
# ['CR Browne ', 'WI)']
# ['NG Cowans ', 'ENG)']
# ['EW Dawson ', 'ENG)']
# ['C Pringle ', 'NZ)']
# ['XC Balaskas ', 'SA)']
# ['SSJ Brooks ', 'WI)']
# ['RJ Inverarity ', 'AUS)']
# ['CR Miller ', 'AUS)']
# ['CH Morris ', 'SA)']
# ['KH Weekes ', 'WI)']
# ['Inshan Ali ', 'WI)']
# ['ST Clarke ', 'WI)']
# ['MF Kent ', 'AUS)']
# ['CS Pandit ', 'INDIA)']
# ['OC Scott ', 'WI)']
# ['GM Carew ', 'WI)']
# ['C Gladwin ', 'ENG)']
# ['MJ Hartigan ', 'AUS)']
# ['J Iddon ', 'ENG)']
# ['C Ramaswami ', 'INDIA)']
# ['Tanvir Ahmed ', 'PAK)']
# ['KC Ibrahim ', 'INDIA)']
# ['RA Young ', 'NZ)']
# ['SE Bond ', 'NZ)']
# ['SH Curnow ', 'SA)']
# ['FGJ Ford ', 'ENG)']
# ['F Hearne ', 'ENG/SA)']
# ['WVS Ling ', 'SA)']
# ['Anil Dalpat ', 'PAK)']
# ['BS Chandrasekhar ', 'INDIA)']
# ['M Watkinson ', 'ENG)']
# ['SW Ambris ', 'WI)']
# ['JP Fellows-Smith ', 'SA)']
# ['EAC Hunte ', 'WI)']
# ['KR Pushpakumara ', 'SL)']
# ['RJ Westcott ', 'SA)']
# ['Abul Hasan ', 'BDESH)']
# ['PK Sen ', 'INDIA)']
# ["ML Su'a ", 'NZ)']
# ['MC Henriques ', 'AUS)']
# ['Mosaddek Hossain ', 'BDESH)']
# ['OJ Pope ', 'ENG)']
# ['PH Punjabi ', 'INDIA)']
# ['A Ratra ', 'INDIA)']
# ['RE Redmond ', 'NZ)']
# ['HD Ackerman ', 'SA)']
# ['CJ Poole ', 'ENG)']
# ['WJ Whitty ', 'AUS)']
# ['EG Arnold ', 'ENG)']
# ['CL Badcock ', 'AUS)']
# ['CI Dunusinghe ', 'SL)']
# ['T Emmett ', 'ENG)']
# ['CH Parkin ', 'ENG)']
# ['OJ Phillips ', 'WI)']
# ['CT Studd ', 'ENG)']
# ['PD Lashley ', 'WI)']
# ['DD Taylor ', 'NZ)']
# ['CEH Croft ', 'WI)']
# ['WP Howell ', 'AUS)']
# ['GF Labrooy ', 'SL)']
# ["DR O'Sullivan ", 'NZ)']
# ['SC Griffith ', 'ENG)']
# ['AP Lucas ', 'ENG)']
# ['DAR Moloney ', 'NZ)']
# ['Naushad Ali ', 'PAK)']
# ['Z de Bruyn ', 'SA)']
# ['Hasan Ali ', 'PAK)']
# ['Rashid Khan ', 'PAK)']
# ['AP Freeman ', 'ENG)']
# ['I Meckiff ', 'AUS)']
# ['SMJ Woods ', 'AUS/ENG)']
# ['Akram Raza ', 'PAK)']
# ['HF Boyle ', 'AUS)']
# ['OC da Costa ', 'WI)']
# ['R Dumbrill ', 'SA)']
# ['RG Gregory ', 'AUS)']
# ['TJ Matthews ', 'AUS)']
# ["J O'Connor ", 'ENG)']
# ['PCR Tufnell ', 'ENG)']
# ['RG de Alwis ', 'SL)']
# ['AJ Pycroft ', 'ZIM)']
# ['EFS Tylecote ', 'ENG)']
# ['FJ Cameron ', 'WI)']
# ['RK Oxenham ', 'AUS)']
# ['SR Patel ', 'ENG)']
# ['WR Playle ', 'NZ)']
# ['W Attewell ', 'ENG)']
# ['AE Fagg ', 'ENG)']
# ['JD Nel ', 'SA)']
# ['GJ Batty ', 'ENG)']
# ['P Kumar ', 'INDIA)']
# ['J Birkenshaw ', 'ENG)']
# ['Ibrahim Zadran ', 'AFG)']
# ['Shadab Kabir ', 'PAK)']
# ['BJT Bosanquet ', 'ENG)']
# ['SC Joseph ', 'WI)']
# ['S Randiv ', 'SL)']
# ['NB Mahwire ', 'ZIM)']
# ['CS Nayudu ', 'INDIA)']
# ['NAT Adcock ', 'SA)']
# ['A Balbirnie ', 'IRE)']
# ['RW McLeod ', 'AUS)']
# ['Sikander Bakht ', 'PAK)']
# ['CL White ', 'AUS)']
# ['Zubayr Hamza ', 'SA)']
# ['Lord Harris ', 'ENG)']
# ['R Howorth ', 'ENG)']
# ['EH Mattis ', 'WI)']
# ['BP Patterson ', 'WI)']
# ['Mohammad Nazir ', 'PAK)']
# ['KR Patterson ', 'AUS)']
# ['W Place ', 'ENG)']
# ['Zulfiqar Babar ', 'PAK)']
# ["EL a'Beckett ", 'AUS)']
# ['RE Marshall ', 'WI)']
# ['CPH Ramanayake ', 'SL)']
# ['JA Warrican ', 'WI)']
# ['SS Dighe ', 'INDIA)']
# ['DRE Joseph ', 'WI)']
# ['GB Lawrence ', 'SA)']
# ['Mohammad Asif ', 'PAK)']
# ['SS Naik ', 'INDIA)']
# ['AL Valentine ', 'WI)']
# ['R Chandrika ', 'WI)']
# ['TS Curtis ', 'ENG)']
# ['GR Robertson ', 'AUS)']
# ['DW Begbie ', 'SA)']
# ['Faheem Ashraf ', 'PAK)']
# ['Hashmatullah Shahidi ', 'AFG)']
# ['DB Pithey ', 'SA)']
# ['FT Badcock ', 'NZ)']
# ['LS Birkett ', 'WI)']
# ["JW D'Arcy ", 'NZ)']
# ['TV Hohns ', 'AUS)']
# ['Rahat Ali ', 'PAK)']
# ['Surendranath ', 'INDIA)']
# ['Afsar Zazai ', 'AFG)']
# ['KBJ Azad ', 'INDIA)']
# ['DB Carr ', 'ENG)']
# ['A Dananjaya ', 'SL)']
# ['Azeem Hafeez ', 'PAK)']
# ['DA Sharpe ', 'PAK)']
# ['N Pradeep ', 'SL)']
# ['TCB Fernando ', 'SL)']
# ['PW Jarvis ', 'ENG)']
# ['E Wainwright ', 'ENG)']
# ['EL Bartlett ', 'WI)']
# ['GC Dyer ', 'AUS)']
# ['DL Piedt ', 'SA)']
# ['V Rathour ', 'INDIA)']
# ['L Tuckett ', 'SA)']
# ['Imran Tahir ', 'SA)']
# ['L Sivaramakrishnan ', 'INDIA)']
# ['Hon.FSG Calthorpe ', 'ENG)']
# ['DR Doshi ', 'INDIA)']
# ['CV Gadkari ', 'INDIA)']
# ['H Gimblett ', 'ENG)']
# ['JR Mason ', 'ENG)']
# ['RW Tolchard ', 'ENG)']
# ['IJ Ward ', 'ENG)']
# ['HR Bromley-Davenport ', 'ENG)']
# ['M Hendrick ', 'ENG)']
# ['RK Illingworth ', 'ENG)']
# ['BP Julian ', 'AUS)']
# ['D Smith ', 'ENG)']
# ['PM Walker ', 'ENG)']
# ['S Chattergoon ', 'WI)']
# ['GR Larsen ', 'NZ)']
# ['AD Mullally ', 'ENG)']
# ['PJR Steyn ', 'SA)']
# ['ES Atkinson ', 'WI)']
# ['NE Haig ', 'ENG)']
# ['JT Hearne ', 'ENG)']
# ['KM Jarvis ', 'ZIM)']
# ['E Jones ', 'AUS)']
# ['DL Bairstow ', 'ENG)']
# ['JB Commins ', 'SA)']
# ['Marshall Ayub ', 'BDESH)']
# ['WFE Marx ', 'SA)']
# ['Nazimuddin ', 'BDESH)']
# ['DM Richards ', 'WI)']
# ['S Samarawickrama ', 'SL)']
# ['CW Wright ', 'ENG)']
# ['HMCM Bandara ', 'SL)']
# ['CJ Chibhabha ', 'ZIM)']
# ['C Overton ', 'ENG)']
# ['DA Reeve ', 'ENG)']
# ['RJ Crisp ', 'SA)']
# ['IB Cromb ', 'NZ)']
# ['Manzoor Elahi ', 'PAK)']
# ['CS Martin ', 'NZ)']
# ['BA Murphy ', 'ZIM)']
# ['Pervez Sajjad ', 'PAK)']
# ['AB Fudadin ', 'WI)']
# ['Junaid Khan ', 'PAK)']
# ['Mohammad Sharif ', 'BDESH)']
# ['AH Omarshah ', 'ZIM)']
# ['EA Brandes ', 'ZIM)']
# ['JG Dewes ', 'ENG)']
# ['TW Wall ', 'AUS)']
# ['A Mithun ', 'INDIA)']
# ['RJ Bailey ', 'ENG)']
# ['MAR Samarasekera ', 'SL)']
# ['AC Smith ', 'ENG)']
# ['BGK Walker ', 'NZ)']
# ['SI de Saram ', 'SL)']
# ['Salahuddin ', 'PAK)']
# ['PADLR Sandakan ', 'SL)']
# ['WH St Hill ', 'WI)']
# ['FJ Cameron ', 'NZ)']
# ['W Farrimond ', 'ENG)']
# ['FM King ', 'WI)']
# ['EA McDonald ', 'AUS)']
# ['F Mitchell ', 'ENG/SA)']
# ['RP Singh ', 'INDIA)']
# ['DH Brain ', 'ZIM)']
# ['PJ Martin ', 'ENG)']
# ['H Morris ', 'ENG)']
# ['Nurul Hasan ', 'BDESH)']
# ['GR Beard ', 'AUS)']
# ['ML Cummins ', 'WI)']
# ['RKJ Dawson ', 'ENG)']
# ['JJ Ferris ', 'AUS/ENG)']
# ['RE Grieveson ', 'SA)']
# ['GPD Hartigan ', 'SA)']
# ['ERT Holmes ', 'ENG)']
# ['AR Whittall ', 'ZIM)']
# ['CFW Allcott ', 'NZ)']
# ['S Haigh ', 'ENG)']
# ['HG Kuhn ', 'SA)']
# ['D Shackleton ', 'ENG)']
# ['EJ Smith ', 'ENG)']
# ['CT Tremlett ', 'ENG)']
# ['EAV Williams ', 'WI)']
# ['ERNS Fernando ', 'SL)']
# ['AG Ganteaume ', 'WI)']
# ['GG Macaulay ', 'ENG)']
# ['GB Stevens ', 'AUS)']
# ['DM Bess ', 'ENG)']
# ['MR Bynoe ', 'WI)']
# ['JD Higgs ', 'AUS)']
# ['HS Kanitkar ', 'INDIA)']
# ['FL Reifer ', 'WI)']
# ['A Shaw ', 'ENG)']
# ['BM Duckett ', 'ENG)']
# ['Ihsanullah ', 'AFG)']
# ['PJ Newport ', 'ENG)']
# ['GE Vivian ', 'NZ)']
# ['TJ Murtagh ', 'IRE)']
# ['SD Udal ', 'ENG)']
# ['Yajurvindra Singh ', 'INDIA)']
# ['JH Board ', 'ENG)']
# ['CG Butts ', 'WI)']
# ['GM Ewing ', 'ZIM)']
# ['Naoomal Jaoomal ', 'INDIA)']
# ['DA Stirling ', 'NZ)']
# ['SJ Cook ', 'SA)']
# ['CB Jennings ', 'AUS)']
# ['AB McDonald ', 'AUS)']
# ['AH McKinnon ', 'SA)']
# ['P Utseya ', 'ZIM)']
# ['EW Dempster ', 'NZ)']
# ['PHT Kaushal ', 'SL)']
# ['CFH Leslie ', 'ENG)']
# ['LS Pascoe ', 'AUS)']
# ['MSK Prasad ', 'INDIA)']
# ['D Ramnarine ', 'WI)']
# ['Rashid Khan ', 'AFG)']
# ['CJE Smith ', 'SA)']
# ['WJ Watson ', 'AUS)']
# ['GE Bradburn ', 'NZ)']
# ['Javed Ahmadi ', 'AFG)']
# ['CB Mpofu ', 'ZIM)']
# ['LS Rajput ', 'INDIA)']
# ['GHT Simpson-Hayward ', 'ENG)']
# ['CJ Adams ', 'ENG)']
# ['GFJ Liebenberg ', 'SA)']
# ['KR Rickards ', 'WI)']
# ['PR Stirling ', 'IRE)']
# ['M Bisset ', 'SA)']
# ['JW Hitch ', 'ENG)']
# ["SB O'Connor ", 'NZ)']
# ['AG Hurst ', 'AUS)']
# ['R Lamba ', 'INDIA)']
# ['RM Prideaux ', 'ENG)']
# ['PM Pushpakumara ', 'SL)']
# ['CIJ Smith ', 'ENG)']
# ['Aaqib Javed ', 'PAK)']
# ['DD Beard ', 'NZ)']
# ['G Challenor ', 'WI)']
# ['SK Coen ', 'SA)']
# ['CS Cowdrey ', 'ENG)']
# ['A Hill ', 'ENG)']
# ['KA Hope ', 'WI)']
# ['TA Harris ', 'SA)']
# ['Khan Mohammad ', 'PAK)']
# ['RD Robinson ', 'AUS)']
# ['HA Furlonge ', 'WI)']
# ['Maninder Singh ', 'INDIA)']
# ['MN Nawaz ', 'SL)']
# ['N Oldfield ', 'ENG)']
# ['Robiul Islam ', 'BDESH)']
# ['Shafiq Ahmed ', 'PAK)']
# ['Shahriar Hossain ', 'BDESH)']
# ['Umar Amin ', 'PAK)']
# ['RK Chauhan ', 'INDIA)']
# ['CM Christiani ', 'WI)']
# ['WM Clark ', 'AUS)']
# ['AC Cummins ', 'WI)']
# ['ELG Hoad ', 'WI)']
# ['S Muthusamy ', 'SA)']
# ['IAR Peebles ', 'ENG)']
# ['V Permaul ', 'WI)']
# ['Aftab Baloch ', 'PAK)']
# ['JC Archer ', 'ENG)']
# ['Hasibul Hossain ', 'BDESH)']
# ['AR Kapoor ', 'INDIA)']
# ['GAE Paine ', 'ENG)']
# ['CP Senanayake ', 'SL)']
# ['LF Townsend ', 'ENG)']
# ['GD Varnals ', 'SA)']
# ['GD Watson ', 'AUS)']
# ['IDR Bradshaw ', 'WI)']
# ['R Clarke ', 'ENG)']
# ['DV Dyer ', 'SA)']
# ['PE McEwan ', 'NZ)']
# ['G MacGregor ', 'ENG)']
# ['KMA Paul ', 'WI)']
# ['WV Rodriguez ', 'WI)']
# ['VH Stollmeyer ', 'WI)']
# ['B Warnapura ', 'SL)']
# ['KJ Abbott ', 'SA)']
# ['HDG Leveson Gower ', 'ENG)']
# ['RP Snell ', 'SA)']
# ['HK Badani ', 'INDIA)']
# ['KS Lokuarachchi ', 'SL)']
# ['Hon.A Lyttelton ', 'ENG)']
# ['K Thomson ', 'NZ)']
# ['T Thushara ', 'SL)']
# ['DJ Vilas ', 'SA)']
# ['AS Wassan ', 'INDIA)']
# ['Yasir Arafat ', 'PAK)']
# ['Asif Masood ', 'PAK)']
# ['MRCN Bandaratilleke ', 'SL)']
# ['OD Gibson ', 'WI)']
# ['J Hunter ', 'ENG)']
# ['AS Kennedy ', 'ENG)']
# ['Mohammad Abbas ', 'PAK)']
# ['PI Philpott ', 'AUS)']
# ['BA Reid ', 'AUS)']
# ['G Bean ', 'ENG)']
# ['AG Milkha Singh ', 'INDIA)']
# ['SD Anurasiri ', 'SL)']
# ['JG Binks ', 'ENG)']
# ['CE Eksteen ', 'SA)']
# ['HC Griffith ', 'WI)']
# ['R Pilling ', 'ENG)']
# ['AK Roy ', 'INDIA)']
# ['Al-Amin Hossain ', 'BDESH)']
# ['T Campbell ', 'SA)']
# ['TL Chatara ', 'ZIM)']
# ['J Cowie ', 'NZ)']
# ['KM Dabengwa ', 'ZIM)']
# ['TN Madondo ', 'ZIM)']
# ['NA Quinn ', 'SA)']
# ['BG Rogers ', 'ZIM)']
# ['GR Hazlitt ', 'AUS)']
# ['G Kishenchand ', 'INDIA)']
# ['RN Lewis ', 'WI)']
# ['PP Ojha ', 'INDIA)']
# ['NM Parker ', 'NZ)']
# ['Tushar Imran ', 'BDESH)']
# ['Ariful Haque ', 'BDESH)']
# ['CK Coventry ', 'ZIM)']
# ['SMS Kaluperuma ', 'SL)']
# ['M Kartik ', 'INDIA)']
# ['TR McKibbin ', 'AUS)']
# ['SW Masakadza ', 'ZIM)']
# ['AN Ranasinghe ', 'SL)']
# ['Shabbir Ahmed ', 'PAK)']
# ['Zulqarnain Haider ', 'PAK)']
# ['ST Callaway ', 'AUS)']
# ['TJ Laughlin ', 'AUS)']
# ['MP Maynard ', 'ENG)']
# ['D Ranatunga ', 'SL)']
# ['ET Smith ', 'ENG)']
# ['AB Tancred ', 'SA)']
# ['GD Elliott ', 'NZ)']
# ['EG Hayes ', 'ENG)']
# ['ND Howard ', 'ENG)']
# ['RC Irani ', 'ENG)']
# ["JDA O'Connor ", 'AUS)']
# ["SNJ O'Keefe ", 'AUS)']
# ['JR Gunn ', 'ENG)']
# ['Mohammad Farooq ', 'PAK)']
# ['SG Shinde ', 'INDIA)']
# ['D Taylor ', 'SA)']
# ['DJ Colley ', 'AUS)']
# ['LA Dawson ', 'ENG)']
# ['AS Joseph ', 'WI)']
# ['RR Jumadeen ', 'WI)']
# ['Yuvraj of Patiala ', 'INDIA)']
# ['MA Seymour ', 'SA)']
# ['U Afzaal ', 'ENG)']
# ['W Barber ', 'ENG)']
# ['J Botha ', 'SA)']
# ['DT Hondo ', 'ZIM)']
# ['SW Sohoni ', 'INDIA)']
# ['JG Thomas ', 'ENG)']
# ['Amir Elahi ', 'INDIA/PAK)']
# ['E Evans ', 'AUS)']
# ['TS Roland-Jones ', 'ENG)']
# ['M Zondeki ', 'SA)']
# ['EE Achong ', 'WI)']
# ['JH de Courcy ', 'AUS)']
# ['GN Francis ', 'WI)']
# ['RA Hamence ', 'AUS)']
# ['ET Killick ', 'ENG)']
# ['AE Knight ', 'ENG)']
# ['SI Mahmood ', 'ENG)']
# ['Manjural Islam ', 'BDESH)']
# ['IL Mendonca ', 'WI)']
# ['WN Slack ', 'ENG)']
# ['JE Barrett ', 'AUS)']
# ['T Duffin ', 'ZIM)']
# ['AEV Hartkopf ', 'AUS)']
# ['JM Kemp ', 'SA)']
# ['RD Parkar ', 'INDIA)']
# ['DJ Sincock ', 'AUS)']
# ['DM Smith ', 'ENG)']
# ['A Wood ', 'ENG)']
# ['TM Chappell ', 'AUS)']
# ['JA Maclean ', 'AUS)']
# ['JA Small ', 'WI)']
# ['A Fielder ', 'ENG)']
# ['MN Lathwell ', 'ENG)']
# ['RAL Massie ', 'AUS)']
# ['SF Mire ', 'ZIM)']
# ['P Bhandari ', 'INDIA)']
# ['A Greenwood ', 'ENG)']
# ['A Nehra ', 'INDIA)']
# ['ASA Perera ', 'SL)']
# ['JN Shepherd ', 'WI)']
# ['DCH Townsend ', 'ENG)']
# ['Ata-ur-Rehman ', 'PAK)']
# ['IG Butler ', 'NZ)']
# ['GHG Doggart ', 'ENG)']
# ['B Dooland ', 'AUS)']
# ["A D'Souza ", 'PAK)']
# ['MR Gillespie ', 'NZ)']
# ['PJ Loader ', 'ENG)']
# ['LC Mayne ', 'AUS)']
# ['F Nicholson ', 'SA)']
# ['RM Poore ', 'SA)']
# ['DW Allan ', 'WI)']
# ['H Donnan ', 'AUS)']
# ['MK Elgie ', 'SA)']
# ['JT Ward ', 'NZ)']
# ['D Wilson ', 'ENG)']
# ['JER Gallian ', 'ENG)']
# ['AG Huckle ', 'ZIM)']
# ['HH Kanitkar ', 'INDIA)']
# ['A Maregwede ', 'ZIM)']
# ['BP Martin ', 'NZ)']
# ['NO Perry ', 'WI)']
# ['Shakeel Ahmed jnr ', 'PAK)']
# ['ET Willett ', 'WI)']
# ['Anamul Haque ', 'BDESH)']
# ['Bilal Asif ', 'PAK)']
# ['JA Hayes ', 'NZ)']
# ['JA McCollum ', 'IRE)']
# ['WE Merritt ', 'NZ)']
# ['DJ Mitchell ', 'NZ)']
# ['JT Partridge ', 'SA)']
# ['EWT Tindill ', 'NZ)']
# ['ERH Toshack ', 'AUS)']
# ['HE Dollery ', 'ENG)']
# ['S Elworthy ', 'SA)']
# ['KO Meth ', 'ZIM)']
# ['TW Routledge ', 'SA)']
# ['A Sanford ', 'WI)']
# ['EG Wynyard ', 'ENG)']
# ['MJ Bennett ', 'AUS)']
# ['WH Brann ', 'SA)']
# ['RO Butcher ', 'ENG)']
# ['AHH Gilligan ', 'ENG)']
# ['DD Hindlekar ', 'INDIA)']
# ['GJ Hopkins ', 'NZ)']
# ['PA Horne ', 'NZ)']
# ['SP James ', 'ENG)']
# ['JJ Krejza ', 'AUS)']
# ['JE Morris ', 'ENG)']
# ['P Roy ', 'INDIA)']
# ['DP Sibley ', 'ENG)']
# ['AW White ', 'WI)']
# ['R Beaumont ', 'SA)']
# ['Bilawal Bhatti ', 'PAK)']
# ['NW Bracken ', 'AUS)']
# ['LG Hylton ', 'WI)']
# ['Nayeem Hasan ', 'BDESH)']
# ['E Peate ', 'ENG)']
# ['GA Smithson ', 'ENG)']
# ['AJ Bell ', 'SA)']
# ['PVD Chameera ', 'SL)']
# ['SHM Colah ', 'INDIA)']
# ['GJ Crocker ', 'ZIM)']
# ['DK Liyanage ', 'SL)']
# ['Mohammad Shahzad ', 'AFG)']
# ['NI Thomson ', 'ENG)']
# ['AC Waller ', 'ZIM)']
# ['WJ Edwards ', 'AUS)']
# ['H Jupp ', 'ENG)']
# ['MG Melle ', 'SA)']
# ['WH Milton ', 'SA)']
# ['Taskin Ahmed ', 'BDESH)']
# ['MR Whitney ', 'AUS)']
# ['JT Ball ', 'ENG)']
# ['MK Mantri ', 'INDIA)']
# ['WD Parnell ', 'SA)']
# ['MW Pringle ', 'SA)']
# ['CP Schofield ', 'ENG)']
# ['MW Sievers ', 'AUS)']
# ['PM Such ', 'ENG)']
# ['NFD Thomson ', 'AUS)']
# ['CV Wight ', 'WI)']
# ['Afaq Hussain ', 'PAK)']
# ['TK Curran ', 'ENG)']
# ['M Hayward ', 'SA)']
# ['RD King ', 'WI)']
# ['A Kuruvilla ', 'INDIA)']
# ['WS Lees ', 'ENG)']
# ['JSE Price ', 'ENG)']
# ['JT Botten ', 'SA)']
# ['WR Cuttell ', 'ENG)']
# ['KSC de Silva ', 'SL)']
# ['RM Edwards ', 'WI)']
# ['CW Henderson ', 'SA)']
# ['AJ Hollioake ', 'ENG)']
# ['WER Somerville ', 'NZ)']
# ['SJ Staples ', 'ENG)']
# ['AP Binns ', 'WI)']
# ['GH Dockrell ', 'IRE)']
# ['ERH Fuller ', 'SA)']
# ['TJD Kelly ', 'AUS)']
# ['JH King ', 'ENG)']
# ['GF Linde ', 'SA)']
# ['ER Mayne ', 'AUS)']
# ['Naved Ashraf ', 'PAK)']
# ['SR Thompson ', 'IRE)']
# ['PE Whitelaw ', 'NZ)']
# ['S Badrinath ', 'INDIA)']
# ['HRJ Charlwood ', 'ENG)']
# ['GWA Chubb ', 'SA)']
# ['CEL Jones ', 'WI)']
# ['Mohammad Munaf ', 'PAK)']
# ['H Philipson ', 'ENG)']
# ['VA Singh ', 'WI)']
# ['NS Asgarali ', 'WI)']
# ['Hon.IFW Bligh ', 'ENG)']
# ['WP Bradburn ', 'NZ)']
# ['CGD Burger ', 'SA)']
# ['RGA Headley ', 'WI)']
# ['KW Hough ', 'NZ)']
# ['C Newberry ', 'SA)']
# ['JA Rennie ', 'ZIM)']
# ['Harry Elliott ', 'ENG)']
# ['Haseeb Ahsan ', 'PAK)']
# ['PJ Ingram ', 'NZ)']
# ['WR James ', 'ZIM)']
# ['NC McGarrell ', 'WI)']
# ['AE Moss ', 'ENG)']
# ...
# ['WE Bowes ', 'ENG)']
# ['CAR Duckworth ', 'SA)']
# ['FAW Freer ', 'AUS)']
# ['SR Gillespie ', 'NZ)']
# ['BP Gupte ', 'INDIA)']
# ['JR Hammond ', 'AUS)']
# ['MC Ilott ', 'ENG)']
# ['RJ Kennedy ', 'NZ)']
# ['Liaqat Ali ', 'PAK)']
# ['CN McCarthy ', 'SA)']
# ['JN Maguire ', 'AUS)']
# ['Mohammad Irfan ', 'PAK)']
# ['RJ Nicol ', 'NZ)']
# ['AT Roberts ', 'WI)']
# ['J Shuter ', 'ENG)']
# ['GB Stevenson ', 'ENG)']
# ['R Vijay Bharadwaj ', 'INDIA)']
# ['MD Wettimuny ', 'SL)']
# ['JA Young ', 'ENG)']
# ['GI Allott ', 'NZ)']
# ['RMH Cottam ', 'ENG)']
# ['LV Garrick ', 'WI)']
# ['RK Kleinveldt ', 'SA)']
# ['J Lewis ', 'ENG)']
# ['NJ Maddinson ', 'AUS)']
# ['RR Singh ', 'INDIA)']
# ['EA van der Merwe ', 'SA)']
# ['AJ Woodcock ', 'AUS)']
# ['RA Young ', 'ENG)']
# ['Atiq-uz-Zaman ', 'PAK)']
# ['IW Callen ', 'AUS)']
# ['TW Cartwright ', 'ENG)']
# ['IA Greig ', 'ENG)']
# ['A Habib ', 'ENG)']
# ['F Kuys ', 'SA)']
# ['PG McShane ', 'AUS)']
# ['JW Martin ', 'ENG)']
# ['W Newham ', 'ENG)']
# ['D Olivier ', 'SA)']
# ['JE Pothecary ', 'SA)']
# ['K Rai Singh ', 'INDIA)']
# ['RR Ramdass ', 'WI)']
# ['GA Rowe ', 'SA)']
# ['GC Viljoen ', 'SA)']
# ['CH Vintcent ', 'SA)']
# ['Atif Rauf ', 'PAK)']
# ['MP Bowden ', 'ENG)']
# ['RG Draper ', 'SA)']
# ['D Ganesh ', 'INDIA)']
# ['GM Griffin ', 'SA)']
# ['LJ Johnson ', 'AUS)']
# ['AJ McKay ', 'NZ)']
# ['CH Mills ', 'SA)']
# ['Mohammad Salman ', 'PAK)']
# ['TA Munton ', 'ENG)']
# ['JM Patel ', 'INDIA)']
# ['RC Saxena ', 'INDIA)']
# ['Shahid Mahmood ', 'PAK)']
# ['IM Sinclair ', 'NZ)']
# ['TF Smailes ', 'ENG)']
# ['DV Smith ', 'ENG)']
# ['VM Tancred ', 'SA)']
# ['GC Tonge ', 'WI)']
# ['SL Watkin ', 'ENG)']
# ['Abu Jayed ', 'BDESH)']
# ['DD Blackie ', 'AUS)']
# ['BP Bracewell ', 'NZ)']
# ['Kabir Khan ', 'PAK)']
# ['NA Knox ', 'ENG)']
# ['SH Lewis ', 'WI)']
# ['MAWR Madurasinghe ', 'SL)']
# ['AM Miller ', 'ENG)']
# ['Mohammad Akram ', 'PAK)']
# ['F Mutizwa ', 'ZIM)']
# ['CEL Stuart ', 'WI)']
# ['Sunzamul Islam ', 'BDESH)']
# ['Zulqarnain ', 'PAK)']
# ['LS Baker ', 'WI)']
# ['VA Barton ', 'ENG)']
# ['WM Bradley ', 'ENG)']
# ['IP Butchart ', 'ZIM)']
# ['PH Carlson ', 'AUS)']
# ['FE Fisher ', 'NZ)']
# ['RA Jones ', 'NZ)']
# ['RC Miller ', 'WI)']
# ['Qais Ahmad ', 'AFG)']
# ['AW Seccull ', 'SA)']
# ['ML Udawatte ', 'SL)']
# ['BA Williams ', 'AUS)']
# ['B Andrews ', 'NZ)']
# ['Anwar Hossain Monir ', 'BDESH)']
# ['RA Austin ', 'WI)']
# ['HR Butt ', 'ENG)']
# ['HG Gaekwad ', 'INDIA)']
# ['C Karunaratne ', 'SL)']
# ['CKB Kulasekara ', 'SL)']
# ['PE McIntyre ', 'AUS)']
# ['G Noblet ', 'AUS)']
# ['CH Palmer ', 'ENG)']
# ['WN Phillips ', 'AUS)']
# ['D Pretorius ', 'SA)']
# ['CAK Rajitha ', 'SL)']
# ['DA Renneberg ', 'AUS)']
# ['SV Samuelson ', 'SA)']
# ['Tareq Aziz ', 'BDESH)']
# ['AL Thomson ', 'AUS)']
# ['RGCE Wijesuriya ', 'SL)']
# ['W Bell ', 'NZ)']
# ['MI Black ', 'WI)']
# ['W Brearley ', 'ENG)']
# ['G Cripps ', 'SA)']
# ['Ehsan Adil ', 'PAK)']
# ['NR Ferreira ', 'ZIM)']
# ['GK Glover ', 'SA)']
# ['JC Hill ', 'AUS)']
# ['AN Hornby ', 'ENG)']
# ['JD Lindsay ', 'SA)']
# ['MJ McCague ', 'ENG)']
# ['GA Manou ', 'AUS)']
# ['WP Masakadza ', 'ZIM)']
# ['T Meale ', 'NZ)']
# ['LE Nagel ', 'AUS)']
# ['DJ Pattinson ', 'ENG)']
# ['NV Radford ', 'ENG)']
# ['JC Reedman ', 'AUS)']
# ['VPFA Royle ', 'ENG)']
# ['J Trim ', 'WI)']
# ['GL Wight ', 'WI)']
# ['RD Woolley ', 'AUS)']
# ['RRS Cornwall ', 'WI)']
# ['HT Davis ', 'NZ)']
# ['F de Wet ', 'SA)']
# ['CJ Eady ', 'AUS)']
# ['I Khan ', 'SA)']
# ['LA Markham ', 'SA)']
# ['T Maruma ', 'ZIM)']
# ['TB Mitchell ', 'ENG)']
# ['Naved Latif ', 'PAK)']
# ['SS Schultz ', 'ENG)']
# ['T Shamsi ', 'SA)']
# ['SW Tait ', 'AUS)']
# ['MF Tremlett ', 'ENG)']
# ['A Wharton ', 'ENG)']
# ['HV Baumgartner ', 'SA)']
# ['DC Cleverley ', 'NZ)']
# ['A Coxon ', 'ENG)']
# ['LP Jai ', 'INDIA)']
# ['S Jeganathan ', 'SL)']
# ['HW Lee ', 'ENG)']
# ['AJW McIntyre ', 'ENG)']
# ['SV Nayak ', 'INDIA)']
# ['AL Phehlukwayo ', 'SA)']
# ['OP Stone ', 'ENG)']
# ['AJ Traicos ', 'SA/ZIM)']
# ['LL Tsotsobe ', 'SA)']
# ['AR Adams ', 'NZ)']
# ['JJ Bumrah ', 'INDIA)']
# ['BB Cooper ', 'AUS)']
# ['AJ Evans ', 'ENG)']
# ['MJ Gopalan ', 'INDIA)']
# ['Gursharan Singh ', 'INDIA)']
# ['C Heseltine ', 'ENG)']
# ['AR McBrine ', 'IRE)']
# ['JE McConnon ', 'ENG)']
# ['EG McLeod ', 'NZ)']
# ['Mohammad Hussain ', 'PAK)']
# ['Mujeeb Ur Rahman ', 'AFG)']
# ['RAP Nissanka ', 'SL)']
# ["NJ O'Brien ", 'IRE)']
# ['Sajedul Islam ', 'BDESH)']
# ['RH Scott ', 'NZ)']
# ['EL St Hill ', 'WI)']
# ['AI Taylor ', 'SA)']
# ['HH Alexander ', 'AUS)']
# ['RT Barber ', 'NZ)']
# ['GD Barlow ', 'ENG)']
# ['GA Briant ', 'ZIM)']
# ['D Brookes ', 'ENG)']
# ['LS Brown ', 'SA)']
# ['S Christopherson ', 'ENG)']
# ['JL Cox ', 'SA)']
# ['DT Dewdney ', 'WI)']
# ['R Dhanraj ', 'WI)']
# ['BBM Gaskin ', 'WI)']
# ['S Guha ', 'INDIA)']
# ['Khalid Hasan ', 'PAK)']
# ['EZ Matambanadzo ', 'ZIM)']
# ['Nasir Jamal ', 'AFG)']
# ['N Ncube ', 'ZIM)']
# ['Niaz Ahmed ', 'PAK)']
# ['AD Pougher ', 'ENG)']
# ['N Reid ', 'SA)']
# ['Sohail Tanvir ', 'PAK)']
# ['PIC Thompson ', 'WI)']
# ['AGD Wickremasinghe ', 'SL)']
# ['M Baqa Jilani ', 'INDIA)']
# ['DV Brennan ', 'ENG)']
# ['RP Burl ', 'ZIM)']
# ['LS Butler ', 'WI)']
# ['W Carkeek ', 'AUS)']
# ['MVT Fernando ', 'SL)']
# ['Imran Khan ', 'PAK)']
# ['CK Langeveldt ', 'SA)']
# ['JDF Larter ', 'ENG)']
# ['James Lillywhite jnr ', 'ENG)']
# ['Muhammad Musa ', 'PAK)']
# ['R Nanan ', 'WI)']
# ['Nazmul Hossain ', 'BDESH)']
# ['JM Neblett ', 'WI)']
# ['AE Ochse ', 'SA)']
# ['MB Owens ', 'NZ)']
# ['JB Plimsoll ', 'SA)']
# ['AW Powell ', 'SA)']
# ['JM Sims ', 'ENG)']
# ['DJ Terbrugge ', 'SA)']
# ['VP Terry ', 'ENG)']
# ['A Waddington ', 'ENG)']
# ['Agha Zahid ', 'PAK)']
# ['Anwar Khan ', 'PAK)']
# ['AL Apte ', 'INDIA)']
# ['HJ Butler ', 'ENG)']
# ['CG Fichardt ', 'SA)']
# ['JC Hartley ', 'ENG)']
# ['PA Hibbert ', 'AUS)']
# ['H Howell ', 'ENG)']
# ['HL Jackson ', 'ENG)']
# ['SS Karim ', 'INDIA)']
# ['C Munro ', 'NZ)']
# ['T Mupariwa ', 'ZIM)']
# ['W Mwayenga ', 'ZIM)']
# ['L Ngidi ', 'SA)']
# ['AW Palm ', 'SA)']
# ['MR Rege ', 'INDIA)']
# ['MWW Selvey ', 'ENG)']
# ['Sohrawordi Shuvo ', 'BDESH)']
# ['MJC Allom ', 'ENG)']
# ['Anwar Hossain ', 'BDESH)']
# ['Azam Khan ', 'PAK)']
# ['Azhar Khan ', 'PAK)']
# ['GF Cresswell ', 'NZ)']
# ['P Hutchinson ', 'SA)']
# ['TE Kane ', 'IRE)']
# ['Khalid Wazir ', 'PAK)']
# ['F Martin ', 'ENG)']
# ['S Morris ', 'AUS)']
# ['PWA Mulder ', 'SA)']
# ['CT Mumba ', 'ZIM)']
# ['B Muzarabani ', 'ZIM)']
# ['MJ Nicholson ', 'AUS)']
# ['ASM Oakman ', 'ENG)']
# ['CT Patankar ', 'INDIA)']
# ['SR Patil ', 'INDIA)']
# ['HLE Promnitz ', 'SA)']
# ['A Rose-Innes ', 'SA)']
# ['Subashis Roy ', 'BDESH)']
# ['NC Tufnell ', 'ENG)']
# ['GF Vernon ', 'ENG)']
# ['KIW Wijegunawardene ', 'SL)']
# ['Ziaur Rahman ', 'BDESH)']
# ['SN Banerjee ', 'INDIA)']
# ['A Coningham ', 'AUS)']
# ['WH Cooper ', 'AUS)']
# ['Hon.CJ Coventry ', 'ENG)']
# ['TWJ Goddard ', 'ENG)']
# ['L Hone ', 'ENG)']
# ['Jubair Hossain ', 'BDESH)']
# ['UN Kulkarni ', 'INDIA)']
# ['HA Musgrove ', 'AUS)']
# ['PWG Parker ', 'ENG)']
# ['R Pollard ', 'ENG)']
# ['RR Powar ', 'INDIA)']
# ['S Ragoonath ', 'WI)']
# ['RT Stanyforth ', 'ENG)']
# ['RB Stewart ', 'SA)']
# ['PHJ Trimborn ', 'SA)']
# ['KP Walmsley ', 'NZ)']
# ['CAK Walton ', 'WI)']
# ['T Yohannan ', 'INDIA)']
# ['CE Floquet ', 'SA)']
# ['Ghulam Abbas ', 'PAK)']
# ['GL Gibbs ', 'WI)']
# ['G Gladstone ', 'WI)']
# ['JL Hopwood ', 'ENG)']
# ['LWS Kaluperuma ', 'SL)']
# ['NT Pascal ', 'WI)']
# ['ACS Pigott ', 'ENG)']
# ['GK Robertson ', 'NZ)']
# ['Shahid Saeed ', 'PAK)']
# ['Wafadar Momand ', 'AFG)']
# ['FH Walters ', 'AUS)']
# ['CD Watson ', 'WI)']
# ['MG Webb ', 'NZ)']
# ['MR Adair ', 'IRE)']
# ['FS Ahangama ', 'SL)']
# ['BJ Bess ', 'WI)']
# ['EG Bock ', 'SA)']
# ['SJE Brown ', 'ENG)']
# ['SS Cottrell ', 'WI)']
# ['WF Giffen ', 'AUS)']
# ['EJ Gregory ', 'AUS)']
# ['TU Groube ', 'AUS)']
# ['GM Guard ', 'INDIA)']
# ['CEJ Guest ', 'AUS)']
# ['AE Hall ', 'SA)']
# ['H Klaasen ', 'SA)']
# ['VM Muddiah ', 'INDIA)']
# ['JM Noreiga ', 'WI)']
# ['AL Ochse ', 'SA)']
# ['G Sharma ', 'INDIA)']
# ['CK Singh ', 'WI)']
# ['J Slight ', 'AUS)']
# ['GB Street ', 'ENG)']
# ['R Vinay Kumar ', 'INDIA)']
# ['MG Waite ', 'AUS)']
# ['KA Walter ', 'SA)']
# ['BT Watambwa ', 'ZIM)']
# ['PN Webb ', 'NZ)']
# ['JJ Whitaker ', 'ENG)']
# ['JP Agnew ', 'ENG)']
# ['Kabir Ali ', 'ENG)']
# ['GD Campbell ', 'AUS)']
# ['B Casson ', 'AUS)']
# ['AC Dawson ', 'SA)']
# ['H Dean ', 'ENG)']
# ['AM de Silva ', 'SL)']
# ['WRS de Silva ', 'SL)']
# ['CJ Drum ', 'NZ)']
# ['GM Emmett ', 'ENG)']
# ['ESH Giddins ', 'ENG)']
# ['JR Hodges ', 'AUS)']
# ['CL Johnson ', 'SA)']
# ['TA Lloyd ', 'ENG)']
# ['CJ McKay ', 'AUS)']
# ['JM Mennie ', 'AUS)']
# ['BD Morrison ', 'NZ)']
# ['DT Mutendera ', 'ZIM)']
# ['AM Pai ', 'INDIA)']
# ['KE Palmer ', 'ENG)']
# ['Pankaj Singh ', 'INDIA)']
# ['SF Rehman ', 'PAK)']
# ['JPF Travers ', 'AUS)']
# ['KEA Upashantha ', 'SL)']
# ['PK Wijetunge ', 'SL)']
# ['ER Wilson ', 'ENG)']
# ['B Yograj Singh ', 'INDIA)']
# ['KN Amalean ', 'SL)']
# ['TS Chisoro ', 'ZIM)']
# ['LJ Coldwell ', 'ENG)']
# ['EQ Davies ', 'SA)']
# ['M de Lange ', 'SA)']
# ['RR Dower ', 'SA)']
# ['A Hearne ', 'ENG)']
# ['Iftikhar Anjum ', 'PAK)']
# ['TF Johnson ', 'WI)']
# ['LR Joslin ', 'AUS)']
# ['J McIlwraith ', 'AUS)']
# ['B Mavuta ', 'ZIM)']
# ['Mohammad Khalil ', 'PAK)']
# ['NO Norton ', 'SA)']
# ['RJ Quiney ', 'AUS)']
# ['Riaz Afridi ', 'PAK)']
# ['GF Rorke ', 'AUS)']
# ['BN Schultz ', 'SA)']
# ['AK Sengupta ', 'INDIA)']
# ['FW Tate ', 'ENG)']
# ['DS Tomlinson ', 'SA)']
# ['Zakir Khan ', 'PAK)']
# ['Agha Saadat Ali ', 'PAK)']
# ['Alamgir Kabir ', 'BDESH)']
# ['HS Chang ', 'WI)']
# ['UG Dowe ', 'WI)']
# ['FJ Durston ', 'ENG)']
# ['PA Emery ', 'AUS)']
# ['N Gordon ', 'SA)']
# ['J Harry ', 'AUS)']
# ['M Henderson ', 'NZ)']
# ['CFW Hime ', 'SA)']
# ['DJ Johnson ', 'INDIA)']
# ['S Kalavitigoda ', 'SL)']
# ['ACI Lock ', 'ZIM)']
# ['HSB Love ', 'AUS)']
# ['DAN McRae ', 'NZ)']
# ['NA Mallender ', 'ENG)']
# ['NE Marshall ', 'WI)']
# ['BD Milburn ', 'NZ)']
# ['Mufasir-ul-Haq ', 'PAK)']
# ["N M'shangwe ", 'ZIM)']
# ['Naseem Shah ', 'PAK)']
# ['GWF Overton ', 'NZ)']
# ['AL Padmore ', 'WI)']
# ['GH Pope ', 'ENG)']
# ['U Ranchod ', 'ZIM)']
# ['CR Rangachari ', 'INDIA)']
# ['KV Sharma ', 'INDIA)']
# ['JT Willoughby ', 'SA)']
# ['RJ Blakey ', 'ENG)']
# ['N Chopra ', 'INDIA)']
# ['FJ Cook ', 'SA)']
# ['Ehsanul Haque ', 'BDESH)']
# ['Faisal Hossain ', 'BDESH)']
# ['WHB Frank ', 'SA)']
# ['RHM Hands ', 'SA)']
# ['RI Harford ', 'NZ)']
# ['Ikram Alikhil ', 'AFG)']
# ['SD Jack ', 'SA)']
# ['CM Kuggeleijn ', 'NZ)']
# ['WHV Levett ', 'ENG)']
# ['TG McMahon ', 'NZ)']
# ['AM Matheson ', 'NZ)']
# ['W Mead ', 'ENG)']
# ['Mohammad Zahid ', 'PAK)']
# ['Munir Malik ', 'PAK)']
# ['S Nyalchand ', 'INDIA)']
# ['GAHM Parkar ', 'INDIA)']
# ['Rafiqul Islam ', 'BDESH)']
# ['Shahid Israr ', 'PAK)']
# ['H Smith ', 'ENG)']
# ['J Southerton ', 'ENG)']
# ['A Warren ', 'ENG)']
# ['DM Washington ', 'WI)']
# ['GEC Wood ', 'ENG)']
# ['SA Ankola ', 'INDIA)']
# ['MA Beer ', 'AUS)']
# ['R Berry ', 'ENG)']
# ['AR Bhat ', 'INDIA)']
# ['JH Cameron ', 'WI)']
# ['PP Chawla ', 'INDIA)']
# ['DP Conyngham ', 'SA)']
# ['AHC Cooper ', 'SA)']
# ['WH Copson ', 'ENG)']
# ['G Coulthard ', 'AUS)']
# ['MS Crane ', 'ENG)']
# ['AC Dale ', 'AUS)']
# ['AR Dell ', 'AUS)']
# ['SH Emery ', 'AUS)']
# ['CE Finlason ', 'SA)']
# ['PLS Gamage ', 'SL)']
# ['RA Gaunt ', 'AUS)']
# ['R Graham ', 'SA)']
# ['Harvinder Singh ', 'INDIA)']
# ['JM Holland ', 'AUS)']
# ['AP Igglesden ', 'ENG)']
# ['VV Kumar ', 'INDIA)']
# ['F Morley ', 'ENG)']
# ['SA Muller ', 'AUS)']
# ['TK Musakanda ', 'ZIM)']
# ['DC Parkin ', 'SA)']
# ['WFF Price ', 'ENG)']
# ['CFH Prince ', 'SA)']
# ['Rajinder Pal ', 'INDIA)']
# ['V Razdan ', 'INDIA)']
# ['AR Richards ', 'SA)']
# ['TL Richmond ', 'ENG)']
# ['MW Rushmere ', 'SA)']
# ['KJ Silva ', 'SL)']
# ['RA Sinfield ', 'ENG)']
# ['R Wood ', 'ENG)']
# ['FE Allan ', 'AUS)']
# ['IBA Allen ', 'WI)']
# ['WM Anderson ', 'NZ)']
# ['SG Borthwick ', 'ENG)']
# ['T Bosch ', 'SA)']
# ['GR Breese ', 'WI)']
# ['GE Corling ', 'AUS)']
# ['A Ducat ', 'ENG)']
# ['KH Eastwood ', 'AUS)']
# ['JN Hamilton ', 'WI)']
# ['A Hurwood ', 'AUS)']
# ['RJD Jamshedji ', 'INDIA)']
# ['HK Jayantilal ', 'INDIA)']
# ['TP Kamungozi ', 'ZIM)']
# ['NM Kulkarni ', 'INDIA)']
# ['FA MacKinnon ', 'ENG)']
# ['Mahbubul Alam ', 'BDESH)']
# ['AP Marr ', 'AUS)']
# ['NO Miller ', 'WI)']
# ['NS Mitchell-Innes ', 'ENG)']
# ['GH Mudie ', 'WI)']
# ['TRO Payne ', 'WI)']
# ['S Prasanna ', 'SL)']
# ['RH Robinson ', 'AUS)']
# ['AHP Scott ', 'WI)']
# ['SMSM Senanayake ', 'SL)']
# ['A Shahzad ', 'ENG)']
# ['GL Tapscott ', 'SA)']
# ['B Arun ', 'INDIA)']
# ['HK Bennett ', 'NZ)']
# ['ID Blackwell ', 'ENG)']
# ['C Burke ', 'NZ)']
# ['FJ Burton ', 'AUS)']
# ['ID Buys ', 'SA)']
# ['JAK Cochran ', 'SA)']
# ['C Cook ', 'ENG)']
# ['JT Cottam ', 'AUS)']
# ['Ebadat Hossain ', 'BDESH)']
# ['CJ Ferguson ', 'AUS)']
# ['H Foley ', 'NZ)']
# ['RA Gleeson ', 'SA)']
# ['T Greenhough ', 'ENG)']
# ['MJ Haslam ', 'NZ)']
# ['Irfan Fazil ', 'PAK)']
# ['MP Jarvis ', 'ZIM)']
# ['Javed Akhtar ', 'PAK)']
# ['GR Loveridge ', 'NZ)']
# ['Mir Hamza ', 'PAK)']
# ['Nazmul Islam ', 'BDESH)']
# ['WHM Richards ', 'SA)']
# ['AM Smith ', 'ENG)']
# ['HD Smith ', 'NZ)']
# ['WRT Solomon ', 'SA)']
# ['Khaled Ahmed ', 'BDESH)']
# ['JO Taylor ', 'WI)']
# ['SN Thakur ', 'INDIA)']
# ['JJ Warr ', 'ENG)']
# ['AJ Webbe ', 'ENG)']
# ['S Young ', 'AUS)']
# ['ST Banerjee ', 'INDIA)']
# ['A Brown ', 'ENG)']
# ['NR Chowdhury ', 'INDIA)']
# ['CB Clarke ', 'WI)']
# ['SH Cook ', 'AUS)']
# ['JRF Duncan ', 'AUS)']
# ['Farooq Hamid ', 'PAK)']
# ['IS Gallage ', 'SL)']
# ['JB Gannon ', 'AUS)']
# ['JK Irani ', 'INDIA)']
# ['JB Iverson ', 'AUS)']
# ['Jalal-ud-Din ', 'PAK)']
# ['IS Madray ', 'WI)']
# ['MJ Mason ', 'NZ)']
# ['CWL Parker ', 'ENG)']
# ['GM Parker ', 'SA)']
# ['RTD Perks ', 'ENG)']
# ['RJ Pope ', 'AUS)']
# ['MA Small ', 'WI)']
# ['CA Smith ', 'ENG)']
# ['MM Sood ', 'INDIA)']
# ['GR Sunderam ', 'INDIA)']
# ['CDUS Weerasinghe ', 'SL)']
# ['AP Wells ', 'ENG)']
# ['LL Wilkinson ', 'ENG)']
# ['JH Childs ', 'ENG)']
# ['V Dahiya ', 'INDIA)']
# ['JF du Toit ', 'SA)']
# ['Ehteshamuddin ', 'PAK)']
# ['DL Freeman ', 'NZ)']
# ['PR George ', 'AUS)']
# ['AR Gover ', 'ENG)']
# ['RSA Jayasekera ', 'SL)']
# ['JJ Kotze ', 'SA)']
# ['RR Kulkarni ', 'INDIA)']
# ['AF Lissette ', 'NZ)']
# ['BE McGain ', 'AUS)']
# ['ES Maka ', 'INDIA)']
# ['ADG Matthews ', 'ENG)']
# ['Qaiser Abbas ', 'PAK)']
# ['Ranjan Das ', 'BDESH)']
# ['WR Robertson ', 'AUS)']
# ['AD Russell ', 'WI)']
# ['RL Sanghvi ', 'INDIA)']
# ['A Sidebottom ', 'ENG)']
# ['HM Taberer ', 'SA)']
# ['KK Tarapore ', 'INDIA)']
# ['NHCD Theunissen ', 'SA)']
# ['JD Unadkat ', 'INDIA)']
# ['L Watt ', 'NZ)']
# ['CA Wiles ', 'WI)']
# ['Aizaz Cheema ', 'PAK)']
# ['Imtiaz Ali ', 'WI)']
# ['Ashfaq Ahmed ', 'PAK)']
# ['WH Ashley ', 'SA)']
# ['MT Chinouya ', 'ZIM)']
# ['IA Colquhoun ', 'NZ)']
# ['Z Crawley ', 'ENG)']
# ['A Dolphin ', 'ENG)']
# ['LH Ferguson ', 'NZ)']
# ['RL Fuller ', 'WI)']
# ['BR Jurangpathy ', 'SL)']
# ['ESM Kentish ', 'WI)']
# ['SC Kerrigan ', 'ENG)']
# ['FL le Roux ', 'SA)']
# ['EB Lundie ', 'SA)']
# ['Miran Bakhsh ', 'PAK)']
# ['S Nadeem ', 'INDIA)']
# ['DD Parsana ', 'INDIA)']
# ['SW Poynter ', 'IRE)']
# ['L Ramji ', 'INDIA)']
# ['JA Richardson ', 'AUS)']
# ['MJ Saggers ', 'ENG)']
# ['DG Sewell ', 'NZ)']
# ['Shakeel Ahmed snr ', 'PAK)']
# ['KN Slater ', 'AUS)']
# ['LB Taylor ', 'ENG)']
# ['G Thornton ', 'SA)']
# ['Waqar Salamkheil ', 'AFG)']
# ['Yasir Ali ', 'PAK)']
# ['MKDI Amerasinghe ', 'SL)']
# ['SA Banerjee ', 'INDIA)']
# ['JE Benjamin ', 'ENG)']
# ['GE Bond ', 'SA)']
# ['LA Butterfield ', 'NZ)']
# ['DW Carr ', 'ENG)']
# ['GA Chevalier ', 'SA)']
# ['SP Davis ', 'AUS)']
# ['CD Dixon ', 'SA)']
# ['JH du Preez ', 'SA)']
# ['GF Grace ', 'ENG)']
# ['RPW Guneratne ', 'SL)']
# ['GG Hall ', 'SA)']
# ['GM Hamilton ', 'ENG)']
# ['MA Hanley ', 'SA)']
# ['GG Hearne ', 'ENG)']
# ['D Hettiarachchi ', 'SL)']
# ['WA Hunt ', 'AUS)']
# ['AS Jaggernauth ', 'WI)']
# ['GA Kempis ', 'SA)']
# ['AK Kuruppuarachchi ', 'SL)']
# ['IB Leggat ', 'NZ)']
# ['PT Lewis ', 'SA)']
# ['JW McLaren ', 'AUS)']
# ['JEP McMaster ', 'ENG)']
# ['CS Marriott ', 'ENG)']
# ['KR Meherhomji ', 'INDIA)']
# ['KD Meuleman ', 'AUS)']
# ['DS Mohanty ', 'INDIA)']
# ['AW Mold ', 'ENG)']
# ['Nadeem Ghauri ', 'PAK)']
# ['M Ngam ', 'SA)']
# ['RL Park ', 'AUS)']
# ['RGM Patel ', 'INDIA)']
# ['KK Peters ', 'WI)']
# ['HJ Rhodes ', 'ENG)']
# ['LA Roberts ', 'WI)']
# ['CG Rowe ', 'NZ)']
# ['CJ Sayers ', 'AUS)']
# ['TAP Sekhar ', 'INDIA)']
# ['RHD Sellers ', 'AUS)']
# ['R Singh ', 'INDIA)']
# ['SD Snooke ', 'SA)']
# ['HM Thurlow ', 'AUS)']
# ['LR Tuckett ', 'SA)']
# ['PS Twentyman-Jones ', 'SA)']
# ['EJ Tyler ', 'ENG)']
# ['M Venkataramana ', 'INDIA)']
# ['DW White ', 'ENG)']
# ['P Wilson ', 'AUS)']
# ['CS Wimble ', 'SA)']
# ['Zahir Khan ', 'AFG)']
# ['Ali Hussain Rizvi ', 'PAK)']
# ['PJ Allan ', 'AUS)']
# ['JC Clay ', 'ENG)']
# ['DJ Cullen ', 'AUS)']
# ['HT Dani ', 'INDIA)']
# ['Farrukh Zaman ', 'PAK)']
# ['AB Howard ', 'WI)']
# ['A Khan ', 'ENG)']
# ['JCW MacBryan ', 'ENG)']
# ['LR Pierre ', 'WI)']
# ['V Rajindernath ', 'INDIA)']
# ['HD Read ', 'ENG)']
# ['CF Root ', 'ENG)']
# ['Shahid Mahboob ', 'PAK)']
# ['RC Shukla ', 'INDIA)']
# ['CA Snedden ', 'NZ)']
# ['VN Swamy ', 'INDIA)']
# ['Usman Shinwari ', 'PAK)']
# ['CM Willoughby ', 'SA)']

# %%
p_name=[]
country=[]
for j in range(3000):
    for i in player[j]:    
        split_values = i.split('(')
        q_name = split_values[0].strip()
        
        coun1 = split_values[1].replace(')', '').strip()


        #print("Player Name:", q_name)
        #print("Nation:", coun1)
        p_name.append(q_name)
        country.append(coun1)

# %%
p_name
# Out:
# ['SR Tendulkar',
#  'RT Ponting',
#  'JH Kallis',
#  'R Dravid',
#  'AN Cook',
#  'KC Sangakkara',
#  'BC Lara',
#  'S Chanderpaul',
#  'DPMD Jayawardene',
#  'AR Border',
#  'SR Waugh',
#  'SM Gavaskar',
#  'Younis Khan',
#  'HM Amla',
#  'GC Smith',
#  'GA Gooch',
#  'Javed Miandad',
#  'Inzamam-ul-Haq',
#  'VVS Laxman',
#  'AB de Villiers',
#  'MJ Clarke',
#  'ML Hayden',
#  'V Sehwag',
#  'IVA Richards',
#  'AJ Stewart',
#  'DI Gower',
#  'KP Pietersen',
#  'G Boycott',
#  'GS Sobers',
#  'ME Waugh',
#  'MA Atherton',
#  'IR Bell',
#  'JL Langer',
#  'MC Cowdrey',
#  'CG Greenidge',
#  'Mohammad Yousuf',
#  'MA Taylor',
#  'CH Lloyd',
#  'DL Haynes',
#  'DC Boon',
#  'JE Root',
#  'G Kirsten',
#  'WR Hammond',
#  'CH Gayle',
#  'SC Ganguly',
#  'V Kohli',
#  'SP Fleming',
#  'SPD Smith',
#  'LRPL Taylor',
#  'GS Chappell',
#  'DA Warner',
#  'AJ Strauss',
#  'DG Bradman',
#  'ST Jayasuriya',
#  'L Hutton',
#  'DB Vengsarkar',
#  'KF Barrington',
#  'GP Thorpe',
#  'BB McCullum',
#  'KS Williamson',
#  'PA de Silva',
#  'MEK Hussey',
#  'RB Kanhai',
#  'M Azharuddin',
#  'HH Gibbs',
#  'RN Harvey',
#  'GR Viswanath',
#  'RB Richardson',
#  'Azhar Ali',
#  'RR Sarwan',
#  'ME Trescothick',
#  'DCS Compton',
#  'Saleem Malik',
#  'N Hussain',
#  'CL Hooper',
#  'CA Pujara',
#  'MP Vaughan',
#  'AD Mathews',
#  'AC Gilchrist',
#  'MV Boucher',
#  'MS Atapattu',
#  'TM Dilshan',
#  'TT Samaraweera',
#  'MD Crowe',
#  'JB Hobbs',
#  'KD Walters',
#  'IM Chappell',
#  'JG Wright',
#  'MJ Slater',
#  'N Kapil Dev',
#  'WM Lawry',
#  'Misbah-ul-Haq',
#  'IT Botham',
#  'JH Edrich',
#  'A Ranatunga',
#  'Zaheer Abbas',
#  'TW Graveney',
#  'MS Dhoni',
#  'RB Simpson',
#  'A Flower',
#  'IR Redpath',
#  'NJ Astle',
#  'AJ Lamb',
#  'H Sutcliffe',
#  'DJ Cullinan',
#  'HP Tillakaratne',
#  'PBH May',
#  'DL Vettori',
#  'Asad Shafiq',
#  'ER Dexter',
#  'ED Weekes',
#  'FDM Karunaratne',
#  'KJ Hughes',
#  'MW Gatting',
#  'DR Martyn',
#  'AI Kallicharran',
#  'APE Knott',
#  'M Amarnath',
#  'IA Healy',
#  'RC Fredericks',
#  'Tamim Iqbal',
#  'MA Butcher',
#  'PD Collingwood',
#  'RA Smith',
#  'Mushfiqur Rahim',
#  'SM Katich',
#  'G Gambhir',
#  'Mudassar Nazar',
#  'AM Rahane',
#  'MJ Prior',
#  'Saeed Anwar',
#  'JM Bairstow',
#  'M Vijay',
#  'Majid Khan',
#  'MN Samuels',
#  'Hanif Mohammad',
#  'Shakib Al Hasan',
#  'FMM Worrell',
#  'LD Chandimal',
#  'A Flintoff',
#  'IJL Trott',
#  'RJ Shastri',
#  'Imran Khan',
#  'F du Plessis',
#  'CL Walcott',
#  'BA Stokes',
#  'SM Pollock',
#  'SR Watson',
#  'WJ Cronje',
#  'D Elgar',
#  'AG Prince',
#  'Mohammad Hafeez',
#  'Mushtaq Mohammad',
#  'RW Marsh',
#  'DM Jones',
#  'PR Umrigar',
#  'BJ Watling',
#  'DL Amiss',
#  'AW Greig',
#  'Asif Iqbal',
#  'TWM Latham',
#  'AR Morris',
#  'EH Hendren',
#  'DM Bravo',
#  'KC Brathwaite',
#  'B Mitchell',
#  'GW Flower',
#  'BE Congdon',
#  'JR Reid',
#  'C Hill',
#  'GA Hick',
#  'GM Wood',
#  'PJL Dujon',
#  'CL Cairns',
#  'Ijaz Ahmed',
#  'FE Woolley',
#  'KWR Fletcher',
#  'BJ Haddin',
#  'ND McKenzie',
#  'CC Hunte',
#  'VL Manjrekar',
#  'NS Sidhu',
#  'HA Gomes',
#  'VT Trumper',
#  'SCJ Broad',
#  'SK Warne',
#  'Sir RJ Hadlee',
#  'CD McMillan',
#  'CC McDonald',
#  'BF Butcher',
#  'WPUJC Vaas',
#  'AL Hassett',
#  'CG Borde',
#  'Habibul Bashar',
#  'JC Adams',
#  'Saeed Ahmed',
#  'GM Turner',
#  'Taufeeq Umar',
#  'AD Nourse',
#  'KR Miller',
#  'HW Taylor',
#  'AH Jones',
#  'D Ramdin',
#  'Wasim Akram',
#  'UT Khawaja',
#  'SL Campbell',
#  'AC Parore',
#  'WW Armstrong',
#  'ADR Campbell',
#  'GR Marsh',
#  'Rameez Raja',
#  'Aamer Sohail',
#  'Wasim Raja',
#  'KR Stackpole',
#  'MAK Pataudi',
#  'KC Wessels',
#  'MM Ali',
#  "NCL O'Neill",
#  'BKG Mendis',
#  'MH Richardson',
#  'M Leyland',
#  'SMH Kirmani',
#  'GN Yallop',
#  'SJ McCabe',
#  'Moin Khan',
#  'Mahmudullah',
#  'Mohammad Ashraful',
#  'B Sutcliffe',
#  'Mohsin Khan',
#  'Shoaib Mohammad',
#  'MG Burgess',
#  'Q de Kock',
#  'JV Coney',
#  'Mominul Haque',
#  'Sarfaraz Ahmed',
#  'Kamran Akmal',
#  'JA Rudolph',
#  'FM Engineer',
#  'WW Hinds',
#  'MJ Guptill',
#  'Sadiq Mohammad',
#  'RD Jacobs',
#  'RS Mahanama',
#  'C Washbrook',
#  'GS Blewett',
#  'JN Rhodes',
#  'GP Howarth',
#  'SM Nurse',
#  'EJ Barlow',
#  'TL Goddard',
#  'A Kumble',
#  "BL D'Oliveira",
#  'AL Logie',
#  'DW Randall',
#  'W Bardsley',
#  'KR Rutherford',
#  'AP Gurusinha',
#  'P Roy',
#  'WJ Edrich',
#  'DJ McGlew',
#  'TG Evans',
#  'LEG Ames',
#  'JHB Waite',
#  'Imran Farhat',
#  'R Ashwin',
#  'MR Ramprakash',
#  'W Rhodes',
#  'S Dhawan',
#  'GT Dowling',
#  'WM Woodfull',
#  'TE Bailey',
#  'PJP Burge',
#  'SE Gregory',
#  'MJK Smith',
#  'SE Marsh',
#  'RG Pollock',
#  'AW Nourse',
#  'Harbhajan Singh',
#  'H Masakadza',
#  'GJ Whittall',
#  'R Benaud',
#  'DJ Bravo',
#  'VS Hazare',
#  'GA Headley',
#  'D Ganga',
#  'JB Stollmeyer',
#  'RG Sharma',
#  'CG Macartney',
#  'HAPW Jayawardene',
#  'WH Ponsford',
#  'RA McLean',
#  'AL Wadekar',
#  'MH Mankad',
#  'JP Duminy',
#  'JK Silva',
#  'AN Petersen',
#  'CPS Chauhan',
#  'Imtiaz Ahmed',
#  'MG Johnson',
#  'K Srikkanth',
#  'RM Cowper',
#  'PE Richardson',
#  'ML Jaisimha',
#  'LG Rowe',
#  'JC Buttler',
#  'SV Manjrekar',
#  'BA Young',
#  'MJ Greatbatch',
#  'CJL Rogers',
#  'KOA Powell',
#  'AC Hudson',
#  'KL Rahul',
#  'DN Sardesai',
#  'TW Hayward',
#  'MA Noble',
#  'DL Murray',
#  'HH Streak',
#  'AD Gaekwad',
#  'G Pullar',
#  'BM McMillan',
#  'EAB Rowan',
#  'JM Parks',
#  'BA Edgar',
#  'Abdul Razzaq',
#  'W Jaffer',
#  'RS Kaluwitharana',
#  'AC MacLaren',
#  'L Klusener',
#  'Yuvraj Singh',
#  'JO Holder',
#  'Shoaib Malik',
#  'RC Russell',
#  'Salman Butt',
#  'PH Parfitt',
#  'N Dickwella',
#  'GRJ Matthews',
#  'RA Jadeja',
#  'BRM Taylor',
#  'RES Wyatt',
#  'R Illingworth',
#  'RP Arnold',
#  'IDS Smith',
#  'T Bavuma',
#  'MD Marshall',
#  'JP Crawley',
#  'DS Lehmann',
#  'Imrul Kayes',
#  'NT Paranavitana',
#  'MJ Horne',
#  'JDP Oram',
#  'BC Booth',
#  'DS Smith',
#  'DM de Silva',
#  'CJ Tavare',
#  'GA Faulkner',
#  'WU Tharanga',
#  'Javed Omar',
#  'HH Dippenaar',
#  'Shahid Afridi',
#  'JE Emburey',
#  'HM Nicholls',
#  'Babar Azam',
#  'VD Philander',
#  'HMRKB Herath',
#  'RL Chase',
#  'GM Ritchie',
#  'KC Bland',
#  'MH Denness',
#  'TG Southee',
#  'BC Broad',
#  'JT Tyldesley',
#  'J Darling',
#  'J Hardstaff jnr',
#  'MS Sinclair',
#  'WR Endean',
#  'RB McCosker',
#  'SV Carlisle',
#  'NJ Contractor',
#  'Yashpal Sharma',
#  'JJ Crowe',
#  'RT Robinson',
#  'M Prabhakar',
#  'AP Sheahan',
#  'WA Brown',
#  'SM Patil',
#  'SB Styris',
#  'RH Catterall',
#  'T Taibu',
#  'E Paynter',
#  'PJ Hughes',
#  'BF Hastings',
#  'KD Mackay',
#  'RR Lindwall',
#  'Qasim Umar',
#  'GS Ballance',
#  'SD Hope',
#  'JM Parker',
#  'RW Barber',
#  'Intikhab Alam',
#  'MA Starc',
#  'Yasir Hameed',
#  'WB Phillips',
#  'AC Voges',
#  'DL Houghton',
#  'A Symonds',
#  'B Lee',
#  'FJ Titmus',
#  'SO Dowrich',
#  'JM Brearley',
#  'NR Mongia',
#  'CEL Ambrose',
#  'WAS Oldfield',
#  'AK Markram',
#  'C Kelleway',
#  'AF Giles',
#  'MS Wade',
#  'Hon.FS Jackson',
#  'MW Goodwin',
#  'RG Nadkarni',
#  'Khaled Mashud',
#  'HDRL Thirimanne',
#  'RT Simpson',
#  'J Ryder',
#  'KLT Arthurton',
#  'Rashid Latif',
#  'GP Swann',
#  'S Ramesh',
#  'Wasim Bari',
#  'KG Viljoen',
#  'J Blackwood',
#  'J Dyson',
#  'DJ Richardson',
#  'HL Collins',
#  'Javed Burki',
#  'BM Laird',
#  'L Vincent',
#  'OG Smith',
#  'LRD Mendis',
#  'AK Davidson',
#  'SS Das',
#  'JS Solomon',
#  'DJG Sammy',
#  'JA Burns',
#  'RA Duff',
#  'N Boje',
#  'G Fowler',
#  'DW Hookes',
#  'CA Davis',
#  'BW Luckhurst',
#  'DR Jardine',
#  'JF Reid',
#  'TD Paine',
#  'RL Dias',
#  'KS More',
#  'JW Burke',
#  'A Shrewsbury snr',
#  'UC Hathurusingha',
#  'JD Ryder',
#  'Shahriar Nafees',
#  'V Pollard',
#  'RF Surti',
#  'M Muralitharan',
#  'MR Marsh',
#  'DW Steyn',
#  'GE Gomez',
#  'HB Cameron',
#  'G Giffen',
#  'WP Saha',
#  'Z Khan',
#  'DG Phadkar',
#  'DD Ebrahim',
#  'CB Fry',
#  'S Wettimuny',
#  'JN Gillespie',
#  'Haroon Rasheed',
#  'G Miller',
#  'VS Ransford',
#  'MDK Perera',
#  'SA Durani',
#  'DN Patel',
#  'MW Tate',
#  'AF Kippax',
#  'JHW Fingleton',
#  'M Labuschagne',
#  'CP Mead',
#  'P Willey',
#  'SC Williams',
#  'JM Anderson',
#  'GS Ramchand',
#  'MTG Elliott',
#  'GO Jones',
#  'Rev.DS Sheppard',
#  'R Edwards',
#  'MJ North',
#  'PM Siddle',
#  'RW Taylor',
#  'BW Sinclair',
#  'JM Gregory',
#  'CR Woakes',
#  'MG Vandort',
#  'Rajin Saleh',
#  'DT Lindsay',
#  'MC Carew',
#  'Faisal Iqbal',
#  'G Gunn',
#  'AC Bannerman',
#  'CC Lewis',
#  'IK Pathan',
#  'BP Nash',
#  'JA Raval',
#  'CJ Barnett',
#  'WG Grace',
#  'CB Wishart',
#  'Alimuddin',
#  'Shan Masood',
#  'VG Kambli',
#  'TM Head',
#  'AMJ Hilditch',
#  'SG Barnes',
#  'Waqar Hasan',
#  'JH Sinclair',
#  'ED Solkar',
#  'JKC Holt',
#  'Mohammad Rafique',
#  'RA Woolmer',
#  'Saleem Yousuf',
#  'C White',
#  'Sarfraz Nawaz',
#  'C de Grandhomme',
#  'Nasir Hossain',
#  'S Madan Lal',
#  'DR Flynn',
#  'MG Hughes',
#  'Abdul Qadir',
#  'RS Madugalle',
#  'KD Karthik',
#  'NM Lyon',
#  'GJ Rennie',
#  'S Abid Ali',
#  'AF Rae',
#  'KJ Wadsworth',
#  'Waqar Younis',
#  'J Srinath',
#  'SJ Snooke',
#  'Umar Akmal',
#  'PV Simmons',
#  'JG Bracewell',
#  'EJM Cowan',
#  'IWG Johnson',
#  'JM Taylor',
#  'AE Stoddart',
#  'KS Duleepsinhji',
#  'AV Mankad',
#  'GE Tyldesley',
#  'KS Ranjitsinhji',
#  'LC Braund',
#  'KA Edwards',
#  'R Subba Row',
#  'JW Zulch',
#  'Ahmed Shehzad',
#  'BK Kunderan',
#  'FS Trueman',
#  'RJ Burns',
#  'B Yardley',
#  'IJ Siedle',
#  'BP Patel',
#  'Junaid Siddique',
#  'PG Fulton',
#  'JWHT Douglas',
#  'FCM Alexander',
#  'SA Thomson',
#  'PS McDonnell',
#  'PR Reiffel',
#  'CA Roach',
#  'G Ulyett',
#  'GD McKenzie',
#  'M Morkel',
#  'CR Ervine',
#  'CJ McDermott',
#  'DL Underwood',
#  'CA Walsh',
#  'PAJ DeFreitas',
#  'PSP Handscomb',
#  'PA Patel',
#  'MDKJ Perera',
#  'Asif Mujtaba',
#  'BL Cairns',
#  'AH Kardar',
#  'Saqlain Mushtaq',
#  'APF Chapman',
#  'DS Atkinson',
#  'CM Spearman',
#  'GHS Trott',
#  'CWJ Athey',
#  'DA Allen',
#  'JR Murray',
#  'KD Ghavri',
#  'MA Holding',
#  'CAG Russell',
#  'WL Murdoch',
#  'DK Lillee',
#  'AFA Lilley',
#  'PA Jaques',
#  'Azhar Mahmood',
#  'BR Taylor',
#  'GJ Cosier',
#  'RJ Christiani',
#  'GF Lawson',
#  'A Melville',
#  'PM Toohey',
#  'SN McGregor',
#  'ATW Grout',
#  'KAJ Roach',
#  'DB Close',
#  'AM Blignaut',
#  'JE Cheetham',
#  'JDB Robertson',
#  'A Sandham',
#  'W Watson',
#  'L Amarnath',
#  'PH Edmonds',
#  'H Carter',
#  'HR Adhikari',
#  'MA Agarwal',
#  'GC White',
#  'HDPK Dharmasena',
#  'BD Julien',
#  'DG Cork',
#  'HJ Tayfield',
#  'AR Caddick',
#  'GRJ Roope',
#  'JDC Goddard',
#  'VM Merchant',
#  'Basit Ali',
#  'JE Taylor',
#  'D Gough',
#  'TG McIntosh',
#  'H Trumble',
#  'CM Old',
#  'RGD Willis',
#  'PA Strang',
#  'SO Hetmyer',
#  'AM Bacher',
#  'RMH Binny',
#  'TJ Franklin',
#  'KJ Funston',
#  'SM Warnapura',
#  'AJ Pithey',
#  'WW Hall',
#  'Sikandar Raza',
#  'Soumya Sarkar',
#  'Khurram Manzoor',
#  'J Briggs',
#  'AR MacGibbon',
#  'TR Veivers',
#  'BR Knight',
#  'NWD Yardley',
#  'AJ Watkins',
#  'TR Gripper',
#  'JEC Franklin',
#  'FA Iredale',
#  'JR Ratnayeke',
#  'JW Hearne',
#  'RAS Lakmal',
#  'Wazir Mohammad',
#  'JM Blackham',
#  'Mashrafe Mortaza',
#  'GH Hirst',
#  'GB Hole',
#  'PJ Sharpe',
#  'MG Bevan',
#  'PR Downton',
#  'CF Walters',
#  'W Mathias',
#  'Mohammad Wasim',
#  'SFAF Bacchus',
#  'KK Jennings',
#  'WK Lees',
#  'CZ Harris',
#  'NRD Compton',
#  'RWT Key',
#  'JM How',
#  'JA Snow',
#  'DAJ Holford',
#  'SK Raina',
#  'A Turner',
#  'AME Roberts',
#  'AJ Hall',
#  'Sami Aslam',
#  'LE Favell',
#  'HD Rutherford',
#  'RR Pant',
#  'Mohammad Amir',
#  'GOB Allen',
#  'S Venkataraghavan',
#  'Nasim-ul-Ghani',
#  'R Abel',
#  'Haris Sohail',
#  'Liton Das',
#  'SJ Harmison',
#  'GAR Lock',
#  'MJ Santner',
#  'PL Symcox',
#  'RS Modi',
#  'EAS Prasanna',
#  'FR Brown',
#  'RW Morgan',
#  'JJ Lyons',
#  'J Arun Lal',
#  'MD Bell',
#  'DJ Nash',
#  'W Barnes',
#  'N Deonarine',
#  'DJ Malan',
#  'CB van Ryneveld',
#  'CS Dempster',
#  'WW Read',
#  'NV Knight',
#  'Asim Kamal',
#  'AV Bedser',
#  'RG Archer',
#  'DG Brownlie',
#  'JDS Neesham',
#  'D Bishoo',
#  'VY Richardson',
#  'I Sharma',
#  'W Bruce',
#  'ARS Silva',
#  'Yasir Shah',
#  'EJG Morgan',
#  'M Ntini',
#  'EL Dalton',
#  'WM Darling',
#  'DR Pringle',
#  'IC Davis',
#  'Hanumant Singh',
#  'Al Sahariar',
#  'CJ Anderson',
#  'FL Fane',
#  'VA Holder',
#  'A Bacher',
#  'JR Thomson',
#  'RW Chakabva',
#  'JC Laker',
#  'JB Statham',
#  'DS Steele',
#  'J Garner',
#  'H Verity',
#  'BA Pocock',
#  'JJ Kelly',
#  'DPB Morkel',
#  'Hannan Sarkar',
#  'AB Barath',
#  'KD Boyce',
#  'W Bates',
#  'BS Bedi',
#  'JFM Morrison',
#  'Mushtaq Ahmed',
#  'Mansoor Akhtar',
#  'C Milburn',
#  'JH Wardle',
#  'AA Donald',
#  'HJH Marshall',
#  'JL Denly',
#  'A Mishra',
#  "KJ O'Keeffe",
#  'GD McGrath',
#  'GS Camacho',
#  'PJ Cummins',
#  'AFG Griffith',
#  'Mehidy Hasan Miraz',
#  'MT Renshaw',
#  'LN Constantine',
#  'IR Bishop',
#  'SC Cook',
#  'HG Deane',
#  'RG Twose',
#  'PN Kirsten',
#  'TW Jarvis',
#  'M Kaif',
#  'PF Warner',
#  'Fazal Mahmood',
#  'JAJ Christy',
#  'UDU Chandana',
#  'TA Boult',
#  'TMK Mawoyo',
#  'RC Motz',
#  'S Mushtaq Ali',
#  'RWV Robins',
#  'JC Watkins',
#  'CS Baugh',
#  'SM Curran',
#  'PM Pollock',
#  'JT Ikin',
#  'RJ Harris',
#  'RE Foster',
#  'DA Murray',
#  'AG Steel',
#  'BAG Murray',
#  'TJE Andrews',
#  'Adnan Akmal',
#  'RG Barlow',
#  'HR Lance',
#  'V Sibanda',
#  'MD Craig',
#  'K Rabada',
#  'MHN Walker',
#  'Alok Kapali',
#  'Aftab Ahmed',
#  'MP Donnelly',
#  'PA Gibb',
#  'MLC Foster',
#  'Umar Gul',
#  'MN Waller',
#  'A Jadeja',
#  'RS Bopara',
#  'TT Bresnan',
#  'AD Hales',
#  'CE McLeod',
#  'RS Morton',
#  'AB Agarkar',
#  'SB Doull',
#  'E Chigumbura',
#  'GL Jessop',
#  'DAJ Bracewell',
#  'KA Maharaj',
#  'Aamer Malik',
#  'EDAS McMorris',
#  'GO Rabone',
#  'CV Grimmett',
#  'MF Maharoof',
#  'GP Wickramasinghe',
#  'SJE Loxton',
#  'N Wagner',
#  'SC Williams',
#  'AG Chipperfield',
#  'B Kumar',
#  'D Lloyd',
#  'S Amarnath',
#  'M Dillon',
#  'Iqbal Qasim',
#  'JM Vince',
#  'CB Llewellyn',
#  'Shoaib Akhtar',
#  'WA Hadlee',
#  'ML Apte',
#  'AG Cremer',
#  'AU Rashid',
#  'LPC Silva',
#  'RA Harper',
#  'RO Collinge',
#  'PJ Moor',
#  'PL van der Merwe',
#  'NC Johnson',
#  'HH Pandya',
#  'S Ranatunga',
#  'Aminul Islam',
#  'CC Griffith',
#  'DR Hadlee',
#  'LJ Tancred',
#  'MD Stoneman',
#  'CL Vincent',
#  'CS Serjeant',
#  'GR Dilley',
#  'Shahadat Hossain',
#  'Nafees Iqbal',
#  'GJ Bonnor',
#  'WW Wade',
#  'WH Scotton',
#  'AJY Hopkins',
#  'BA Richards',
#  'Maqsood Ahmed',
#  'JT Murray',
#  'RO Hinds',
#  'BJ Hodge',
#  'BK Shepherd',
#  'Taslim Arif',
#  'ME Chapple',
#  'JB Bolus',
#  'W Larkins',
#  'ML Page',
#  'LR Gibbs',
#  'Mohammad Sami',
#  'A Ward',
#  'SJ Benn',
#  'FR Martin',
#  'Imam-ul-Haq',
#  'H Larwood',
#  'CE Pellew',
#  'GJ Gilmour',
#  'PR Sleep',
#  'CT Radley',
#  'Sabbir Rahman',
#  'RH Spooner',
#  'BW Yuile',
#  'JED Sealy',
#  'J Worrall',
#  'KTGD Prasad',
#  'LS Darling',
#  'A Jackson',
#  'MJ Hoggard',
#  'TP Horan',
#  'SB Bangar',
#  'WKM Benjamin',
#  'JT Brown',
#  'JN Crawford',
#  'AB Williams',
#  'PM Nevill',
#  'GH Vihari',
#  'BC Strang',
#  'RJ Peterson',
#  'JM Read',
#  'PL Harris',
#  'PGV van der Bijl',
#  'CL McCool',
#  'TA Ward',
#  'VJ Scott',
#  'A Cotter',
#  'AR Lewis',
#  'TE Blain',
#  'TM Moody',
#  'JM Blanckenberg',
#  'DAS Gunaratne',
#  'MD Moxon',
#  'BH Pairaudeau',
#  'BH Valentine',
#  'B Wood',
#  'Mohammed Shami',
#  'Saeed Ajmal',
#  'MA Vermeulen',
#  'WV Raman',
#  'IS Sodhi',
#  'TR Ambrose',
#  'TJ Friend',
#  'JL Hendriks',
#  'CT Bancroft',
#  'NA Foster',
#  'RJ Bright',
#  'MS Kasprowicz',
#  'CD Cumming',
#  'Mohammad Ilyas',
#  'JW Guy',
#  'RM Hogg',
#  'WM Wallace',
#  'A Chopra',
#  'Saleem Elahi',
#  'RJ Ratnayake',
#  'PL Taylor',
#  'AA Mallett',
#  'AA Baig',
#  'TB de Bruyn',
#  'SP Jones',
#  'Imran Nazir',
#  'R Peel',
#  'PW Sherwell',
#  'DR Tuffey',
#  'NM Hauritz',
#  'DT Ring',
#  'PK Amre',
#  'D Denton',
#  'RW Anderson',
#  'AG Kripal Singh',
#  'GG Arnold',
#  'RDB Croft',
#  'HG Vivian',
#  'RB Desai',
#  'CK Kapugedera',
#  'CL King',
#  'Naeem Islam',
#  'AE Relf',
#  'GL Weir',
#  'JL Pattinson',
#  'GC Grant',
#  'AG Fairfax',
#  "WJ O'Reilly",
#  'AH Bakewell',
#  'DJ Insole',
#  'DBL Powell',
#  'DS de Silva',
#  'JH Hampshire',
#  'LR Johnson',
#  'AJ Richardson',
#  'NS Yadav',
#  'JR Hazlewood',
#  'TL Best',
#  'KE Rigg',
#  'BN Jarman',
#  'NBF Mann',
#  'M van Jaarsveld',
#  'C Sharma',
#  'Abdur Rehman',
#  'JW Gleeson',
#  'Shujauddin',
#  'S van Zyl',
#  'JEF Beck',
#  'FH Edwards',
#  'SJ Rixon',
#  'D Tallon',
#  'W Gunn',
#  'CL Smith',
#  ...]

# %%
country
# Out:
# ['INDIA',
#  'AUS',
#  'ICC/SA',
#  'ICC/INDIA',
#  'ENG',
#  'SL',
#  'ICC/WI',
#  'WI',
#  'SL',
#  'AUS',
#  'AUS',
#  'INDIA',
#  'PAK',
#  'SA',
#  'ICC/SA',
#  'ENG',
#  'PAK',
#  'ICC/PAK',
#  'INDIA',
#  'SA',
#  'AUS',
#  'AUS',
#  'ICC/INDIA',
#  'WI',
#  'ENG',
#  'ENG',
#  'ENG',
#  'ENG',
#  'WI',
#  'AUS',
#  'ENG',
#  'ENG',
#  'AUS',
#  'ENG',
#  'WI',
#  'PAK',
#  'AUS',
#  'WI',
#  'WI',
#  'AUS',
#  'ENG',
#  'SA',
#  'ENG',
#  'WI',
#  'INDIA',
#  'INDIA',
#  'NZ',
#  'AUS',
#  'NZ',
#  'AUS',
#  'AUS',
#  'ENG',
#  'AUS',
#  'SL',
#  'ENG',
#  'INDIA',
#  'ENG',
#  'ENG',
#  'NZ',
#  'NZ',
#  'SL',
#  'AUS',
#  'WI',
#  'INDIA',
#  'SA',
#  'AUS',
#  'INDIA',
#  'WI',
#  'PAK',
#  'WI',
#  'ENG',
#  'ENG',
#  'PAK',
#  'ENG',
#  'WI',
#  'INDIA',
#  'ENG',
#  'SL',
#  'AUS',
#  'ICC/SA',
#  'SL',
#  'SL',
#  'SL',
#  'NZ',
#  'ENG',
#  'AUS',
#  'AUS',
#  'NZ',
#  'AUS',
#  'INDIA',
#  'AUS',
#  'PAK',
#  'ENG',
#  'ENG',
#  'SL',
#  'PAK',
#  'ENG',
#  'INDIA',
#  'AUS',
#  'ZIM',
#  'AUS',
#  'NZ',
#  'ENG',
#  'ENG',
#  'SA',
#  'SL',
#  'ENG',
#  'ICC/NZ',
#  'PAK',
#  'ENG',
#  'WI',
#  'SL',
#  'AUS',
#  'ENG',
#  'AUS',
#  'WI',
#  'ENG',
#  'INDIA',
#  'AUS',
#  'WI',
#  'BDESH',
#  'ENG',
#  'ENG',
#  'ENG',
#  'BDESH',
#  'AUS',
#  'INDIA',
#  'PAK',
#  'INDIA',
#  'ENG',
#  'PAK',
#  'ENG',
#  'INDIA',
#  'PAK',
#  'WI',
#  'PAK',
#  'BDESH',
#  'WI',
#  'SL',
#  'ENG/ICC',
#  'ENG',
#  'INDIA',
#  'PAK',
#  'SA',
#  'WI',
#  'ENG',
#  'SA',
#  'AUS',
#  'SA',
#  'SA',
#  'SA',
#  'PAK',
#  'PAK',
#  'AUS',
#  'AUS',
#  'INDIA',
#  'NZ',
#  'ENG',
#  'ENG',
#  'PAK',
#  'NZ',
#  'AUS',
#  'ENG',
#  'WI',
#  'WI',
#  'SA',
#  'ZIM',
#  'NZ',
#  'NZ',
#  'AUS',
#  'ENG',
#  'AUS',
#  'WI',
#  'NZ',
#  'PAK',
#  'ENG',
#  'ENG',
#  'AUS',
#  'SA',
#  'WI',
#  'INDIA',
#  'INDIA',
#  'WI',
#  'AUS',
#  'ENG',
#  'AUS',
#  'NZ',
#  'NZ',
#  'AUS',
#  'WI',
#  'SL',
#  'AUS',
#  'INDIA',
#  'BDESH',
#  'WI',
#  'PAK',
#  'NZ',
#  'PAK',
#  'SA',
#  'AUS',
#  'SA',
#  'NZ',
#  'WI',
#  'PAK',
#  'AUS',
#  'WI',
#  'NZ',
#  'AUS',
#  'ZIM',
#  'AUS',
#  'PAK',
#  'PAK',
#  'PAK',
#  'AUS',
#  'INDIA',
#  'AUS/SA',
#  'ENG',
#  'AUS',
#  'SL',
#  'NZ',
#  'ENG',
#  'INDIA',
#  'AUS',
#  'AUS',
#  'PAK',
#  'BDESH',
#  'BDESH',
#  'NZ',
#  'PAK',
#  'PAK',
#  'NZ',
#  'SA',
#  'NZ',
#  'BDESH',
#  'PAK',
#  'PAK',
#  'SA',
#  'INDIA',
#  'WI',
#  'NZ',
#  'PAK',
#  'WI',
#  'SL',
#  'ENG',
#  'AUS',
#  'SA',
#  'NZ',
#  'WI',
#  'SA',
#  'SA',
#  'INDIA',
#  'ENG',
#  'WI',
#  'ENG',
#  'AUS',
#  'NZ',
#  'SL',
#  'INDIA',
#  'ENG',
#  'SA',
#  'ENG',
#  'ENG',
#  'SA',
#  'PAK',
#  'INDIA',
#  'ENG',
#  'ENG',
#  'INDIA',
#  'NZ',
#  'AUS',
#  'ENG',
#  'AUS',
#  'AUS',
#  'ENG',
#  'AUS',
#  'SA',
#  'SA',
#  'INDIA',
#  'ZIM',
#  'ZIM',
#  'AUS',
#  'WI',
#  'INDIA',
#  'WI',
#  'WI',
#  'WI',
#  'INDIA',
#  'AUS',
#  'SL',
#  'AUS',
#  'SA',
#  'INDIA',
#  'INDIA',
#  'SA',
#  'SL',
#  'SA',
#  'INDIA',
#  'PAK',
#  'AUS',
#  'INDIA',
#  'AUS',
#  'ENG',
#  'INDIA',
#  'WI',
#  'ENG',
#  'INDIA',
#  'NZ',
#  'NZ',
#  'AUS',
#  'WI',
#  'SA',
#  'INDIA',
#  'INDIA',
#  'ENG',
#  'AUS',
#  'WI',
#  'ZIM',
#  'INDIA',
#  'ENG',
#  'SA',
#  'SA',
#  'ENG',
#  'NZ',
#  'PAK',
#  'INDIA',
#  'SL',
#  'ENG',
#  'SA',
#  'INDIA',
#  'WI',
#  'PAK',
#  'ENG',
#  'PAK',
#  'ENG',
#  'SL',
#  'AUS',
#  'INDIA',
#  'ZIM',
#  'ENG',
#  'ENG',
#  'SL',
#  'NZ',
#  'SA',
#  'WI',
#  'ENG',
#  'AUS',
#  'BDESH',
#  'SL',
#  'NZ',
#  'NZ',
#  'AUS',
#  'WI',
#  'SL',
#  'ENG',
#  'SA',
#  'SL',
#  'BDESH',
#  'SA',
#  'PAK',
#  'ENG',
#  'NZ',
#  'PAK',
#  'SA',
#  'SL',
#  'WI',
#  'AUS',
#  'SA',
#  'ENG',
#  'NZ',
#  'ENG',
#  'ENG',
#  'AUS',
#  'ENG',
#  'NZ',
#  'SA',
#  'AUS',
#  'ZIM',
#  'INDIA',
#  'INDIA',
#  'NZ',
#  'ENG',
#  'INDIA',
#  'AUS',
#  'AUS',
#  'INDIA',
#  'NZ',
#  'SA',
#  'ZIM',
#  'ENG',
#  'AUS',
#  'NZ',
#  'AUS',
#  'AUS',
#  'PAK',
#  'ENG',
#  'WI',
#  'NZ',
#  'ENG',
#  'PAK',
#  'AUS',
#  'PAK',
#  'AUS',
#  'AUS',
#  'ZIM',
#  'AUS',
#  'AUS',
#  'ENG',
#  'WI',
#  'ENG',
#  'INDIA',
#  'WI',
#  'AUS',
#  'SA',
#  'AUS',
#  'ENG',
#  'AUS',
#  'ENG',
#  'ZIM',
#  'INDIA',
#  'BDESH',
#  'SL',
#  'ENG',
#  'AUS',
#  'WI',
#  'PAK',
#  'ENG',
#  'INDIA',
#  'PAK',
#  'SA',
#  'WI',
#  'AUS',
#  'SA',
#  'AUS',
#  'PAK',
#  'AUS',
#  'NZ',
#  'WI',
#  'SL',
#  'AUS',
#  'INDIA',
#  'WI',
#  'WI',
#  'AUS',
#  'AUS',
#  'SA',
#  'ENG',
#  'AUS',
#  'WI',
#  'ENG',
#  'ENG',
#  'NZ',
#  'AUS',
#  'SL',
#  'INDIA',
#  'AUS',
#  'ENG',
#  'SL',
#  'NZ',
#  'BDESH',
#  'NZ',
#  'INDIA',
#  'ICC/SL',
#  'AUS',
#  'SA',
#  'WI',
#  'SA',
#  'AUS',
#  'INDIA',
#  'INDIA',
#  'INDIA',
#  'ZIM',
#  'ENG',
#  'SL',
#  'AUS',
#  'PAK',
#  'ENG',
#  'AUS',
#  'SL',
#  'INDIA',
#  'NZ',
#  'ENG',
#  'AUS',
#  'AUS',
#  'AUS',
#  'ENG',
#  'ENG',
#  'WI',
#  'ENG',
#  'INDIA',
#  'AUS',
#  'ENG',
#  'ENG',
#  'AUS',
#  'AUS',
#  'AUS',
#  'ENG',
#  'NZ',
#  'AUS',
#  'ENG',
#  'SL',
#  'BDESH',
#  'SA',
#  'WI',
#  'PAK',
#  'ENG',
#  'AUS',
#  'ENG',
#  'INDIA',
#  'WI',
#  'NZ',
#  'ENG',
#  'ENG',
#  'ZIM',
#  'PAK',
#  'PAK',
#  'INDIA',
#  'AUS',
#  'AUS',
#  'AUS',
#  'PAK',
#  'SA',
#  'INDIA',
#  'WI',
#  'BDESH',
#  'ENG',
#  'PAK',
#  'ENG',
#  'PAK',
#  'NZ',
#  'BDESH',
#  'INDIA',
#  'NZ',
#  'AUS',
#  'PAK',
#  'SL',
#  'INDIA',
#  'AUS',
#  'ZIM',
#  'INDIA',
#  'WI',
#  'NZ',
#  'PAK',
#  'INDIA',
#  'SA',
#  'PAK',
#  'WI',
#  'NZ',
#  'AUS',
#  'AUS',
#  'AUS',
#  'ENG',
#  'ENG',
#  'INDIA',
#  'ENG',
#  'ENG',
#  'ENG',
#  'WI',
#  'ENG',
#  'SA',
#  'PAK',
#  'INDIA',
#  'ENG',
#  'ENG',
#  'AUS',
#  'SA',
#  'INDIA',
#  'BDESH',
#  'NZ',
#  'ENG',
#  'WI',
#  'NZ',
#  'AUS',
#  'AUS',
#  'WI',
#  'ENG',
#  'AUS',
#  'SA',
#  'ZIM',
#  'AUS',
#  'ENG',
#  'WI',
#  'ENG',
#  'AUS',
#  'INDIA',
#  'SL',
#  'PAK',
#  'NZ',
#  'INDIA/PAK',
#  'PAK',
#  'ENG',
#  'WI',
#  'NZ',
#  'AUS',
#  'ENG',
#  'ENG',
#  'WI',
#  'INDIA',
#  'WI',
#  'ENG',
#  'AUS/ENG',
#  'AUS',
#  'ENG',
#  'AUS',
#  'PAK',
#  'NZ',
#  'AUS',
#  'WI',
#  'AUS',
#  'SA',
#  'AUS',
#  'NZ',
#  'AUS',
#  'WI',
#  'ENG',
#  'ZIM',
#  'SA',
#  'ENG',
#  'ENG',
#  'ENG',
#  'INDIA',
#  'ENG',
#  'AUS',
#  'INDIA',
#  'INDIA',
#  'SA',
#  'SL',
#  'WI',
#  'ENG',
#  'SA',
#  'ENG',
#  'ENG',
#  'WI',
#  'INDIA',
#  'PAK',
#  'WI',
#  'ENG',
#  'NZ',
#  'AUS',
#  'ENG',
#  'ENG',
#  'ZIM',
#  'WI',
#  'SA',
#  'INDIA',
#  'NZ',
#  'SA',
#  'SL',
#  'SA',
#  'WI',
#  'ZIM',
#  'BDESH',
#  'PAK',
#  'ENG',
#  'NZ',
#  'AUS',
#  'ENG',
#  'ENG',
#  'ENG',
#  'ZIM',
#  'NZ',
#  'AUS',
#  'SL',
#  'ENG',
#  'SL',
#  'PAK',
#  'AUS',
#  'BDESH',
#  'ENG',
#  'AUS',
#  'ENG',
#  'AUS',
#  'ENG',
#  'ENG',
#  'PAK',
#  'PAK',
#  'WI',
#  'ENG',
#  'NZ',
#  'NZ',
#  'ENG',
#  'ENG',
#  'NZ',
#  'ENG',
#  'WI',
#  'INDIA',
#  'AUS',
#  'WI',
#  'SA',
#  'PAK',
#  'AUS',
#  'NZ',
#  'INDIA',
#  'PAK',
#  'ENG',
#  'INDIA',
#  'PAK',
#  'ENG',
#  'PAK',
#  'BDESH',
#  'ENG/ICC',
#  'ENG',
#  'NZ',
#  'SA',
#  'INDIA',
#  'INDIA',
#  'ENG',
#  'NZ',
#  'AUS',
#  'INDIA',
#  'NZ',
#  'NZ',
#  'ENG',
#  'WI',
#  'ENG',
#  'SA',
#  'NZ',
#  'ENG',
#  'ENG',
#  'PAK',
#  'ENG',
#  'AUS',
#  'NZ',
#  'NZ',
#  'WI',
#  'AUS',
#  'INDIA',
#  'AUS',
#  'SL',
#  'PAK',
#  'ENG',
#  'SA',
#  'SA',
#  'AUS',
#  'ENG',
#  'AUS',
#  'INDIA',
#  'BDESH',
#  'NZ',
#  'ENG',
#  'WI',
#  'SA',
#  'AUS',
#  'ZIM',
#  'ENG',
#  'ENG',
#  'ENG',
#  'WI',
#  'ENG',
#  'NZ',
#  'AUS',
#  'SA',
#  'BDESH',
#  'WI',
#  'WI',
#  'ENG',
#  'INDIA',
#  'NZ',
#  'PAK',
#  'PAK',
#  'ENG',
#  'ENG',
#  'SA',
#  'NZ',
#  'ENG',
#  'INDIA',
#  'AUS',
#  'AUS',
#  'WI',
#  'AUS',
#  'WI',
#  'BDESH',
#  'AUS',
#  'WI',
#  'WI',
#  'SA',
#  'SA',
#  'NZ',
#  'SA',
#  'NZ',
#  'INDIA',
#  'ENG',
#  'PAK',
#  'SA',
#  'SL',
#  'NZ',
#  'ZIM',
#  'NZ',
#  'INDIA',
#  'ENG',
#  'SA',
#  'WI',
#  'ENG',
#  'SA',
#  'ENG',
#  'AUS',
#  'ENG',
#  'WI',
#  'ENG',
#  'NZ',
#  'AUS',
#  'PAK',
#  'ENG',
#  'SA',
#  'ZIM',
#  'NZ',
#  'SA',
#  'AUS',
#  'BDESH',
#  'BDESH',
#  'NZ',
#  'ENG',
#  'WI',
#  'PAK',
#  'ZIM',
#  'INDIA',
#  'ENG',
#  'ENG',
#  'ENG',
#  'AUS',
#  'WI',
#  'INDIA',
#  'NZ',
#  'ZIM',
#  'ENG',
#  'NZ',
#  'SA',
#  'PAK',
#  'WI',
#  'NZ',
#  'AUS',
#  'SL',
#  'SL',
#  'AUS',
#  'NZ',
#  'ZIM',
#  'AUS',
#  'INDIA',
#  'ENG',
#  'INDIA',
#  'WI',
#  'PAK',
#  'ENG',
#  'SA',
#  'PAK',
#  'NZ',
#  'INDIA',
#  'ZIM',
#  'ENG',
#  'SL',
#  'WI',
#  'NZ',
#  'ZIM',
#  'SA',
#  'ZIM',
#  'INDIA',
#  'SL',
#  'BDESH',
#  'WI',
#  'NZ',
#  'SA',
#  'ENG',
#  'SA',
#  'AUS',
#  'ENG',
#  'BDESH',
#  'BDESH',
#  'AUS',
#  'SA',
#  'ENG',
#  'AUS',
#  'SA',
#  'PAK',
#  'ENG',
#  'WI',
#  'AUS',
#  'AUS',
#  'PAK',
#  'NZ',
#  'ENG',
#  'ENG',
#  'NZ',
#  'WI',
#  'PAK',
#  'ENG',
#  'WI',
#  'WI',
#  'PAK',
#  'ENG',
#  'AUS',
#  'AUS',
#  'AUS',
#  'ENG',
#  'BDESH',
#  'ENG',
#  'NZ',
#  'WI',
#  'AUS',
#  'SL',
#  'AUS',
#  'AUS',
#  'ENG',
#  'AUS',
#  'INDIA',
#  'WI',
#  'ENG',
#  'ENG',
#  'WI',
#  'AUS',
#  'INDIA',
#  'ZIM',
#  'SA',
#  'ENG',
#  'SA',
#  'SA',
#  'AUS',
#  'SA',
#  'NZ',
#  'AUS',
#  'ENG',
#  'NZ',
#  'AUS',
#  'SA',
#  'SL',
#  'ENG',
#  'WI',
#  'ENG',
#  'ENG',
#  'INDIA',
#  'PAK',
#  'ZIM',
#  'INDIA',
#  'NZ',
#  'ENG',
#  'ZIM',
#  'WI',
#  'AUS',
#  'ENG',
#  'AUS',
#  'AUS',
#  'NZ',
#  'PAK',
#  'NZ',
#  'AUS',
#  'NZ',
#  'INDIA',
#  'PAK',
#  'SL',
#  'AUS',
#  'AUS',
#  'INDIA',
#  'SA',
#  'AUS',
#  'PAK',
#  'ENG',
#  'SA',
#  'NZ',
#  'AUS',
#  'AUS',
#  'INDIA',
#  'ENG',
#  'NZ',
#  'INDIA',
#  'ENG',
#  'ENG',
#  'NZ',
#  'INDIA',
#  'SL',
#  'WI',
#  'BDESH',
#  'ENG',
#  'NZ',
#  'AUS',
#  'WI',
#  'AUS',
#  'AUS',
#  'ENG',
#  'ENG',
#  'WI',
#  'SL',
#  'ENG',
#  'WI',
#  'AUS',
#  'INDIA',
#  'AUS',
#  'WI',
#  'AUS',
#  'AUS',
#  'SA',
#  'SA',
#  'INDIA',
#  'PAK',
#  'AUS',
#  'PAK',
#  'SA',
#  'NZ',
#  'WI',
#  'AUS',
#  'AUS',
#  'ENG',
#  'ENG',
#  ...]

# %%
d={'plyerName':p_name,'Country':country}

# %%
x=pd.DataFrame(d)

# %%
x
# Out:
#            plyerName    Country
# 0       SR Tendulkar      INDIA
# 1         RT Ponting        AUS
# 2          JH Kallis     ICC/SA
# 3           R Dravid  ICC/INDIA
# 4            AN Cook        ENG
# ...              ...        ...
# 2995       RC Shukla      INDIA
# 2996      CA Snedden         NZ
# 2997        VN Swamy      INDIA
# 2998  Usman Shinwari        PAK
# 2999   CM Willoughby         SA
#
# [3000 rows x 2 columns]

# %%
y=df.iloc[:,2:]

# %%
y
# Out:
#            Span  Mat Inns  NO   Runs    HS    Ave 100  50   0
# 0     1989-2013  200  329  33  15921  248*  53.78  51  68  14
# 1     1995-2012  168  287  29  13378   257  51.85  41  62  17
# 2     1995-2013  166  280  40  13289   224  55.37  45  58  16
# 3     1996-2012  164  286  32  13288   270  52.31  36  63   8
# 4     2006-2018  161  291  16  12472   294  45.35  33  57   9
# ...         ...  ...  ...  ..    ...   ...    ...  ..  ..  ..
# 2996  1947-1947    1    0   0      0     0      0   0   0   0
# 2997  1955-1955    1    0   0      0     0      0   0   0   0
# 2998  2019-2019    1    0   0      0     0      0   0   0   0
# 2999  2003-2003    2    0   0      0     0      0   0   0   0
# 3000  1956-1956    1    0   0      0     0      0   0   0   0
#
# [3001 rows x 10 columns]

# %%
cricket=pd.concat([x,y],axis=1)

# %%
cricket
# Out:
#            plyerName    Country       Span  Mat Inns  NO   Runs    HS    Ave  \
# 0       SR Tendulkar      INDIA  1989-2013  200  329  33  15921  248*  53.78
# 1         RT Ponting        AUS  1995-2012  168  287  29  13378   257  51.85
# 2          JH Kallis     ICC/SA  1995-2013  166  280  40  13289   224  55.37
# 3           R Dravid  ICC/INDIA  1996-2012  164  286  32  13288   270  52.31
# 4            AN Cook        ENG  2006-2018  161  291  16  12472   294  45.35
# ...              ...        ...        ...  ...  ...  ..    ...   ...    ...
# 2996      CA Snedden         NZ  1947-1947    1    0   0      0     0      0
# 2997        VN Swamy      INDIA  1955-1955    1    0   0      0     0      0
# 2998  Usman Shinwari        PAK  2019-2019    1    0   0      0     0      0
# 2999   CM Willoughby         SA  2003-2003    2    0   0      0     0      0
# 3000             NaN        NaN  1956-1956    1    0   0      0     0      0
#
#      100  50   0
# 0     51  68  14
# 1     41  62  17
# 2     45  58  16
# 3     36  63   8
# 4     33  57   9
# ...   ..  ..  ..
# 2996   0   0   0
# 2997   0   0   0
# 2998   0   0   0
# 2999   0   0   0
# 3000   0   0   0
#
# [3001 rows x 12 columns]

# %%
cricket=cricket.iloc[:-1]

# %%
cricket
# Out:
#            plyerName    Country       Span  Mat Inns  NO   Runs    HS    Ave  \
# 0       SR Tendulkar      INDIA  1989-2013  200  329  33  15921  248*  53.78
# 1         RT Ponting        AUS  1995-2012  168  287  29  13378   257  51.85
# 2          JH Kallis     ICC/SA  1995-2013  166  280  40  13289   224  55.37
# 3           R Dravid  ICC/INDIA  1996-2012  164  286  32  13288   270  52.31
# 4            AN Cook        ENG  2006-2018  161  291  16  12472   294  45.35
# ...              ...        ...        ...  ...  ...  ..    ...   ...    ...
# 2995       RC Shukla      INDIA  1982-1982    1    0   0      0     0      0
# 2996      CA Snedden         NZ  1947-1947    1    0   0      0     0      0
# 2997        VN Swamy      INDIA  1955-1955    1    0   0      0     0      0
# 2998  Usman Shinwari        PAK  2019-2019    1    0   0      0     0      0
# 2999   CM Willoughby         SA  2003-2003    2    0   0      0     0      0
#
#      100  50   0
# 0     51  68  14
# 1     41  62  17
# 2     45  58  16
# 3     36  63   8
# 4     33  57   9
# ...   ..  ..  ..
# 2995   0   0   0
# 2996   0   0   0
# 2997   0   0   0
# 2998   0   0   0
# 2999   0   0   0
#
# [3000 rows x 12 columns]

# %%
cricket.to_csv("cricket1",index=False)

# %%
player=cricket.iloc[:,1:2]
player=np.array(player)
player
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 player=cricket.iloc[:,1:2]
#       2 player=np.array(player)
#       3 player
#
# NameError: name 'cricket' is not defined
